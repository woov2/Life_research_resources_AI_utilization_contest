# %% [markdown]
# # 암환자 유전체 데이터 기반 암종 분류 AI 모델 개발
#
#
# - '2024 생명연구자원 AI활용 경진대회'는 바이오 데이터를 기반으로 한 AI 기술의 문제 해결 능력을 탐구하는 것을 목표로 합니다. <br>이 대회는 바이오 분야에서 AI 활용의 저변을 확대하고, 복잡한 바이오 데이터를 효율적으로 분석 및 해석할 수 있는 AI 알고리즘 개발에 초점을 맞추고 있습니다. <br><br>
# - 본 대회의 구체적인 과제는 암환자 유전체 데이터의 변이 정보를 활용하여 암종을 분류하는 AI 모델을 개발하는 것입니다. <br>참가자들은 제공된 학습 데이터셋(암환자 유전체 변이 정보)을 사용하여 특정 변이 정보를 바탕으로 암종을 정확하게 분류할 수 있는 AI 알고리즘을 개발해야 합니다. <br><br>
# - 이 대회의 궁극적인 목적은 바이오 데이터의 활용도를 높이고, 바이오 분야에서 AI 기술의 적용 가능성을 극대화하며, 인공지능 기술이 실제 바이오 의료 문제 해결에 어떻게 기여할 수 있는지 탐구하는 것입니다.

# %% [markdown]
# # VERSIONS #
# ### GPU 0 : NVIDIA GeForce RTX 3080 Ti Laptop GPU
# ### GPU 1 : AMD Radeon(TM) Graphics
# ### CPU : AMD Ryzen 9 6900HX with Radeon Graphics
#
# ### -------------------------- Python & library version --------------------------
# ### Python version: 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]
# ### pandas version: 2.0.3
# ### numpy version: 1.21.5
# ### matplotlib version: 3.5.2
# ### tqdm version: 4.64.1
# ### xgboost version: 1.7.2
# ### lightgbm version: 3.3.3
# ### catboost version: 1.1.1
# ### scikit-learn version: 1.0.2
# ------------------------------------------------------------------------------

# %%
# <!-- from google.colab import drive
# drive.mount('/content/drive')# Import library -->

import pandas as pd
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
import xgboost as xgb
from tqdm import tqdm  # tqdm 임포트
import random
import os
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
seed_everything(42) # Seed 고정

# %%
train = pd.read_csv('1019_final_tr_2.csv')
test = pd.read_csv('1019_final_te_2.csv')

# %%
import numpy as np

# train.loc[train['SUBCLASS']=='GBM','SUBCLASS'] = 'GBMLGG'
# train.loc[train['SUBCLASS']=='GBMLGG','SUBCLASS'] = np.nan
# train.loc[train['SUBCLASS']=='KIPAN','SUBCLASS'] =  np.nan

train.loc[train['SUBCLASS']=='READ','SUBCLASS'] = np.nan
train.loc[train['SUBCLASS']=='UVM','SUBCLASS'] = np.nan
train.loc[train['SUBCLASS']=='UCS','SUBCLASS'] = np.nan
train.loc[train['SUBCLASS']=='CHOL','SUBCLASS'] = np.nan
train.loc[train['SUBCLASS']=='KIRP','SUBCLASS'] = 'KIPAN'
train.loc[train['SUBCLASS']=='KICH','SUBCLASS'] = 'KIPAN'
train.loc[train['SUBCLASS']=='KIRC','SUBCLASS'] = 'KIRC'

train.loc[train['SUBCLASS']=='STAD','SUBCLASS'] = 'STES'
train.loc[train['SUBCLASS']=='ESCA','SUBCLASS'] = 'STES'
train = train.dropna(subset=['SUBCLASS'])

train = train.reset_index(drop=True)

# %%
wt_indices = train.iloc[:, 2:].apply(lambda row: (row == 'WT').all(), axis=1)
result_indices = train[wt_indices].index
print(len(result_indices))
train = train.drop(result_indices)
train = train.reset_index(drop=True)
# Out:
# 94

# %% [markdown]
# # Changing data

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import re
# 1. 아미노산 변환 사전 정의
amino_acid_dict = {
    'A': 'Alanine',
    'R': 'Arginine',
    'N': 'Asparagine',
    'D': 'Aspartic acid',
    'C': 'Cysteine',
    'E': 'Glutamic acid',
    'Q': 'Glutamine',
    'G': 'Glycine',
    'H': 'Histidine',
    'I': 'Isoleucine',
    'L': 'Leucine',
    'K': 'Lysine',
    'M': 'Methionine',
    'F': 'Phenylalanine',
    'P': 'Proline',
    'S': 'Serine',
    'T': 'Threonine',
    'W': 'Tryptophan',
    'Y': 'Tyrosine',
    'V': 'Valine',
    '*' :'Stop Codon',
    'X' : 'UnKnown'
}

def translate_amino_acids(sequence, amino_acid_dict):
    translated = [amino_acid_dict.get(aa, "Unknown") for aa in sequence]
    return ", ".join(translated)

# Function to interpret mutation notation
def interpret_mutation_with_col_name(gene, mutation_code):
    if mutation_code == "WT" or not isinstance(mutation_code, str) or len(mutation_code) < 2:
        return None  # Skip wild-type entries, non-string entries, or too-short strings

    # Split the mutation code by spaces to handle multiple mutations in one cell
    mutations = mutation_code.split(' ')
    descriptions = []

    for mutation in mutations:
        description = None  # Initialize description for each mutation
        if '-' in mutation and 'fs' in mutation:
            # Extract the position (e.g., -5026fs -> position 5026)
            position = mutation.split('fs')[0]  # Split at 'fs' and take the first part
            position = position.replace('-', '')  # Remove '-' to get the numeric position

            # Create description for the frameshift mutation
            description = f" {gene},  frameshift  {position}"

        elif 'fs' in mutation:
            # Handle frameshift mutations
            if mutation[1].isalpha():  # 숫자가 아닐 때 (알파벳일 때)
                original_aa_1 = mutation[0]
                original_aa_1 = amino_acid_dict.get(original_aa_1, "Unknown")

                original_aa_2 = mutation[1]
                original_aa_2 = amino_acid_dict.get(original_aa_2, "Unknown")

                position = mutation[2:-2]  # Exclude 'fs' from position
                description = f" {gene},  frameshift {original_aa_1}  {original_aa_2}  {position}"
            else:
                original_aa = mutation[0]
                original_aa = amino_acid_dict.get(original_aa, "Unknown")

                position = mutation[1:-2]  # Exclude 'fs' from position
                description = f" {gene},  frameshift  {original_aa}  {position}"

        elif '*' in mutation:
            if mutation[0]=='*' :
                position = mutation[1:-1]
                new_aa = mutation[-1]
                new_aa = amino_acid_dict.get(new_aa, "Unknown")
                description = f"{gene}, stop codon {position} changes to {new_aa}"

            else:
                # Handle stop codon mutations
                original_aa = mutation[0]
                original_aa = amino_acid_dict.get(original_aa, "Unknown")

                position = mutation[1:-1]  # Position before the *
                description = f"{gene}, {original_aa} {position} changes to stop codon"

        elif 'delins' in mutation:
            # Handle deletion-insertion mutations
            match = re.match(r"([A-Za-z]+)(\d+)_([A-Za-z]+)(\d+)delins([A-Za-z]+)", mutation)
            if match:
                original_aa_start = match.group(1)
                start_position = match.group(2)
                original_aa_end = match.group(3)
                end_position = match.group(4)
                inserted_seq = match.group(5)

                # Translate amino acids using dictionary
                original_aa_start = amino_acid_dict.get(original_aa_start, "Unknown")
                original_aa_end = amino_acid_dict.get(original_aa_end, "Unknown")
                inserted_seq_translated = translate_amino_acids(inserted_seq, amino_acid_dict)

                description = f"{gene} {start_position} ({original_aa_start}) to {end_position} ({original_aa_end}), a del is followed by ins of {inserted_seq_translated}"

        elif 'ins' in mutation:
            # Handle insertion mutations
            match = re.match(r"([A-Za-z]+)(\d+)ins([A-Za-z]+)", mutation)
            if match:
                original_aa = match.group(1)
                position = match.group(2)
                inserted_seq = match.group(3)

                # Translate amino acids using dictionary
                original_aa = amino_acid_dict.get(original_aa, "Unknown")
                inserted_seq_translated = translate_amino_acids(inserted_seq, amino_acid_dict)

                description = f"{gene}, {inserted_seq_translated} ins {position} {original_aa}"

        elif 'del' in mutation:
            # Handle deletion mutations (modified regex to capture both amino acids and positions)
            match = re.match(r"([A-Za-z]+)(\d+)del", mutation)
            if match:
                original_aa_start = match.group(1)
                start_position = match.group(2)
#                 original_aa_end = match.group(3)
#                 end_position = match.group(4)

                # Translate amino acids using dictionary
                original_aa_start = amino_acid_dict.get(original_aa_start, "Unknown")
#                 original_aa_end = amino_acid_dict.get(original_aa_end, "Unknown")

                description = f"{gene}, {start_position}, ({original_aa_start}) is del"

        elif 'dup' in mutation:
            # Handle duplication mutations (modified regex to capture both amino acids and positions)
            match = re.match(r"([A-Za-z]+)(\d+)dup", mutation)
            if match:
                original_aa_start = match.group(1)
                start_position = match.group(2)
#                 original_aa_end = match.group(3)
#                 end_position = match.group(4)

                # Translate amino acids using dictionary
                original_aa_start = amino_acid_dict.get(original_aa_start, "Unknown")
#                 original_aa_end = amino_acid_dict.get(original_aa_end, "Unknown")

                description = f"{gene} {start_position} ({original_aa_start}) dup"

        elif len(mutation) >= 2 and mutation[0] == mutation[-1]:
            # Handle mutations where the original and new amino acid are the same (e.g., S1866S)
            original_aa = mutation[0]
            original_aa = amino_acid_dict.get(original_aa, "Unknown")

            position = mutation[1:-1]
            description = f"{gene}, {original_aa} {position} changes {original_aa}"

        elif len(mutation) >= 2 and mutation[0] != mutation[-1]:
            # Handle mutations where the original and new amino acid are different
            original_aa = mutation[0]
            original_aa = amino_acid_dict.get(original_aa, "Unknown")

            position = mutation[1:-1]
            new_aa = mutation[-1]
            new_aa = amino_acid_dict.get(new_aa, "Unknown")

            description = f" {gene}, {original_aa}  changes  {new_aa} {position}"

        else:
            # Handle general mutations
            match = re.match(r"([A-Za-z]+)(\d+)", mutation)

            if match:
                original_aa = match.group(1)  # 'T'
                position = match.group(2)     # '218'
                original_aa = amino_acid_dict.get(original_aa, "Unknown")
                description = f"{gene}, {original_aa} is changes del or ins {position}"

        if description:
            descriptions.append(description)

    return "; ".join(descriptions)

# Train 데이터 돌연변이 설명 생성
train['mutation_description'] = ""
for index, row in train.iterrows():
    mutation_descriptions = []
    for gene, mutation in row.items():
        if gene != 'SUBCLASS' and mutation != "WT" and gene != 'ID':
            description = interpret_mutation_with_col_name(gene, mutation)
            if description:
                mutation_descriptions.append(description)
    full_description = "; ".join(mutation_descriptions)
    train.at[index, 'mutation_description'] = full_description

# Test 데이터 돌연변이 설명 생성
test['mutation_description'] = ""
for index, row in test.iterrows():
    mutation_descriptions = []
    for gene, mutation in row.items():
        if gene != 'SUBCLASS' and mutation != "WT" and gene != 'ID':
            description = interpret_mutation_with_col_name(gene, mutation)
            if description:
                mutation_descriptions.append(description)
    full_description = "; ".join(mutation_descriptions)
    test.at[index, 'mutation_description'] = full_description

df_test = test['mutation_description']
df_train = train[["SUBCLASS", "mutation_description"]]

# TF-IDF Vectorizer 초기화 및 학습
vectorizer = TfidfVectorizer(max_features=40000)

# train 데이터를 이용해 TF-IDF 모델을 학습 (fit)
vectorizer.fit(df_train['mutation_description'])

# train 데이터를 변환 (transform)
train_tfidf = vectorizer.transform(df_train['mutation_description'])

# test 데이터를 변환 (transform)
test_tfidf = vectorizer.transform(df_test)

# 결과 출력
print("Train TF-IDF shape:", train_tfidf.shape)
print("Test TF-IDF shape:", test_tfidf.shape)

# 희소 행렬을 밀집 행렬로 변환
train_data = pd.DataFrame(train_tfidf.toarray())
test_data = pd.DataFrame(test_tfidf.toarray())
# Out:
# Train TF-IDF shape: (39874, 28122)
# Test TF-IDF shape: (2546, 28122)

# %%
# SUBCLASS 범주형 데이터를 숫자로 변환 (LabelEncoder 사용)
train_data['SUBCLASS'] = df_train['SUBCLASS']
le_subclass = LabelEncoder()
train_data['SUBCLASS'] = le_subclass.fit_transform(train_data['SUBCLASS'])

# 변환된 레이블 확인
for i, label in enumerate(le_subclass.classes_):
    print(f"원래 레이블: {label}, 변환된 숫자: {i}")

# Feature와 Target 분리
X = train_data.drop(columns=['SUBCLASS'])
y = train_data['SUBCLASS']
X_test = test_data
# Out:
# 원래 레이블: ACC, 변환된 숫자: 0
# 원래 레이블: BLCA, 변환된 숫자: 1
# 원래 레이블: BRCA, 변환된 숫자: 2
# 원래 레이블: CESC, 변환된 숫자: 3
# 원래 레이블: COAD, 변환된 숫자: 4
# 원래 레이블: DLBC, 변환된 숫자: 5
# 원래 레이블: GBMLGG, 변환된 숫자: 6
# 원래 레이블: HNSC, 변환된 숫자: 7
# 원래 레이블: KIPAN, 변환된 숫자: 8
# 원래 레이블: KIRC, 변환된 숫자: 9
# 원래 레이블: LAML, 변환된 숫자: 10
# 원래 레이블: LGG, 변환된 숫자: 11
# 원래 레이블: LIHC, 변환된 숫자: 12
# 원래 레이블: LUAD, 변환된 숫자: 13
# 원래 레이블: LUSC, 변환된 숫자: 14
# 원래 레이블: OV, 변환된 숫자: 15
# 원래 레이블: PAAD, 변환된 숫자: 16
# 원래 레이블: PCPG, 변환된 숫자: 17
# 원래 레이블: PRAD, 변환된 숫자: 18
# 원래 레이블: SARC, 변환된 숫자: 19
# 원래 레이블: SKCM, 변환된 숫자: 20
# 원래 레이블: STES, 변환된 숫자: 21
# 원래 레이블: TGCT, 변환된 숫자: 22
# 원래 레이블: THCA, 변환된 숫자: 23
# 원래 레이블: THYM, 변환된 숫자: 24
# 원래 레이블: UCEC, 변환된 숫자: 25

# %%
import pandas as pd
import numpy as np
import lightgbm as lgbm
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils.class_weight import compute_sample_weight  # 이 부분이 추가됩니다.


# 입력 데이터 설정
trt = X
y = y
models = []

# Stratified K-Fold 설정
for seed in range(0, 1):  # 시드를 여러 개로 설정하여 평균내기

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    evals_result = {}
    test_preds = []

    # Stratified K-Fold를 사용하여 모델 학습
    for train_index, test_index in skf.split(trt, y):
        X_train, X_val = trt.iloc[train_index], trt.iloc[test_index]
        y_train, y_val = y[train_index], y[test_index]

        print(X_train.shape, X_val.shape)

        y_pred_list = []
    #     for seed in range(42, 43):  # 시드를 여러 개로 설정하여 평균내기

        sample_weight = compute_sample_weight(class_weight='balanced', y=y_train)

        dtrain = lgbm.Dataset(X_train, y_train)#, weight=sample_weight)
        dvalid = lgbm.Dataset(X_val, y_val)
        print(f"Seed: {seed}")
        params = {
            "objective": "multiclass",
            "num_class": len(np.unique(y)),  # 클래스 수 지정
            "metric": "multi_logloss",
            "verbosity": -1,
            "boosting_type": "gbdt",
            "max_depth": 6,
            "num_leaves": 300,
            "learning_rate": 0.1,
            "lambda_l1": 0,
            "lambda_l2": 0,
            "bagging_fraction": 0.5,
            "feature_fraction": 0.5,
            "early_stopping_round": 20,
            "max_bin": 35,
            "seed": seed ,
            # "is_unbalance": False,  # 직접 가중치를 적용하기 때문에 False로 설정
            # "class_weight": class_weights_dict  # 클래스 가중치 적용
        }

        model = lgbm.train(
            params,
            dtrain,
            valid_sets=[dvalid],
            num_boost_round=4000,
            #early_stopping_rounds=100,  # 조기 종료 라운드
            #verbose_eval=100
        )

        # 예측 수행
        y_pred = model.predict(X_val)
        y_pred_list.append(y_pred)

        # 다중 분류 F1-Score 계산 (average=None 사용)
        y_pred_avg = np.argmax(np.mean(y_pred_list, axis=0), axis=1)
        f1_per_class = f1_score(y_val, y_pred_avg, average=None)

        # 각 클래스별 F1 Score 출력
        for idx, score in enumerate(f1_per_class):
            print(f"F1 Score for class {idx}: {score}")

        # Overall Macro F1 Score
        f1_macro = f1_score(y_val, y_pred_avg, average='macro')
        print(f"Overall F1 Score (Macro): {f1_macro}")

        models.append(model)
# Out:
# (31899, 28122) (7975, 28122)
# Seed: 0
# [1]	valid_0's multi_logloss: 2.72135
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's multi_logloss: 2.53992
# [3]	valid_0's multi_logloss: 2.39961
# [4]	valid_0's multi_logloss: 2.2933
# [5]	valid_0's multi_logloss: 2.20673
# [6]	valid_0's multi_logloss: 2.13654
# [7]	valid_0's multi_logloss: 2.0753
# [8]	valid_0's multi_logloss: 2.01853
# [9]	valid_0's multi_logloss: 1.97264
# [10]	valid_0's multi_logloss: 1.92628
# [11]	valid_0's multi_logloss: 1.8906
# [12]	valid_0's multi_logloss: 1.85536
# [13]	valid_0's multi_logloss: 1.82146
# [14]	valid_0's multi_logloss: 1.7953
# [15]	valid_0's multi_logloss: 1.76908
# [16]	valid_0's multi_logloss: 1.74505
# [17]	valid_0's multi_logloss: 1.7221
# [18]	valid_0's multi_logloss: 1.6997
# [19]	valid_0's multi_logloss: 1.68025
# [20]	valid_0's multi_logloss: 1.66011
# [21]	valid_0's multi_logloss: 1.64242
# [22]	valid_0's multi_logloss: 1.62317
# [23]	valid_0's multi_logloss: 1.60823
# [24]	valid_0's multi_logloss: 1.59275
# [25]	valid_0's multi_logloss: 1.57744
# [26]	valid_0's multi_logloss: 1.56379
# [27]	valid_0's multi_logloss: 1.55075
# [28]	valid_0's multi_logloss: 1.53667
# [29]	valid_0's multi_logloss: 1.52445
# [30]	valid_0's multi_logloss: 1.51324
# [31]	valid_0's multi_logloss: 1.50222
# [32]	valid_0's multi_logloss: 1.49264
# [33]	valid_0's multi_logloss: 1.48313
# [34]	valid_0's multi_logloss: 1.47363
# [35]	valid_0's multi_logloss: 1.46407
# [36]	valid_0's multi_logloss: 1.4562
# [37]	valid_0's multi_logloss: 1.44808
# [38]	valid_0's multi_logloss: 1.43945
# [39]	valid_0's multi_logloss: 1.4317
# [40]	valid_0's multi_logloss: 1.42482
# [41]	valid_0's multi_logloss: 1.4163
# [42]	valid_0's multi_logloss: 1.40926
# [43]	valid_0's multi_logloss: 1.40312
# [44]	valid_0's multi_logloss: 1.39676
# [45]	valid_0's multi_logloss: 1.39183
# [46]	valid_0's multi_logloss: 1.38631
# [47]	valid_0's multi_logloss: 1.3796
# [48]	valid_0's multi_logloss: 1.37413
# [49]	valid_0's multi_logloss: 1.36891
# [50]	valid_0's multi_logloss: 1.36387
# [51]	valid_0's multi_logloss: 1.35869
# [52]	valid_0's multi_logloss: 1.35308
# [53]	valid_0's multi_logloss: 1.34902
# [54]	valid_0's multi_logloss: 1.34452
# [55]	valid_0's multi_logloss: 1.33887
# [56]	valid_0's multi_logloss: 1.33489
# [57]	valid_0's multi_logloss: 1.3297
# [58]	valid_0's multi_logloss: 1.32603
# [59]	valid_0's multi_logloss: 1.32171
# [60]	valid_0's multi_logloss: 1.31753
# [61]	valid_0's multi_logloss: 1.31332
# [62]	valid_0's multi_logloss: 1.31022
# [63]	valid_0's multi_logloss: 1.3057
# [64]	valid_0's multi_logloss: 1.30218
# [65]	valid_0's multi_logloss: 1.29892
# [66]	valid_0's multi_logloss: 1.29556
# [67]	valid_0's multi_logloss: 1.29158
# [68]	valid_0's multi_logloss: 1.28831
# [69]	valid_0's multi_logloss: 1.28487
# [70]	valid_0's multi_logloss: 1.28089
# [71]	valid_0's multi_logloss: 1.27743
# [72]	valid_0's multi_logloss: 1.2743
# [73]	valid_0's multi_logloss: 1.27125
# [74]	valid_0's multi_logloss: 1.26824
# [75]	valid_0's multi_logloss: 1.26573
# [76]	valid_0's multi_logloss: 1.26232
# [77]	valid_0's multi_logloss: 1.25948
# [78]	valid_0's multi_logloss: 1.25701
# [79]	valid_0's multi_logloss: 1.25481
# [80]	valid_0's multi_logloss: 1.25236
# [81]	valid_0's multi_logloss: 1.24877
# [82]	valid_0's multi_logloss: 1.24628
# [83]	valid_0's multi_logloss: 1.24308
# [84]	valid_0's multi_logloss: 1.2406
# [85]	valid_0's multi_logloss: 1.23756
# [86]	valid_0's multi_logloss: 1.23476
# [87]	valid_0's multi_logloss: 1.23214
# [88]	valid_0's multi_logloss: 1.22929
# [89]	valid_0's multi_logloss: 1.2271
# [90]	valid_0's multi_logloss: 1.22422
# [91]	valid_0's multi_logloss: 1.22187
# [92]	valid_0's multi_logloss: 1.21939
# [93]	valid_0's multi_logloss: 1.21667
# [94]	valid_0's multi_logloss: 1.21462
# [95]	valid_0's multi_logloss: 1.21248
# [96]	valid_0's multi_logloss: 1.21024
# [97]	valid_0's multi_logloss: 1.20808
# [98]	valid_0's multi_logloss: 1.20543
# [99]	valid_0's multi_logloss: 1.20377
# [100]	valid_0's multi_logloss: 1.20195
# [101]	valid_0's multi_logloss: 1.19967
# [102]	valid_0's multi_logloss: 1.19704
# [103]	valid_0's multi_logloss: 1.19526
# [104]	valid_0's multi_logloss: 1.19315
# [105]	valid_0's multi_logloss: 1.19125
# [106]	valid_0's multi_logloss: 1.18935
# [107]	valid_0's multi_logloss: 1.18756
# [108]	valid_0's multi_logloss: 1.18542
# [109]	valid_0's multi_logloss: 1.18376
# [110]	valid_0's multi_logloss: 1.18182
# [111]	valid_0's multi_logloss: 1.18012
# [112]	valid_0's multi_logloss: 1.17847
# [113]	valid_0's multi_logloss: 1.17675
# [114]	valid_0's multi_logloss: 1.17464
# [115]	valid_0's multi_logloss: 1.17267
# [116]	valid_0's multi_logloss: 1.17089
# [117]	valid_0's multi_logloss: 1.16953
# [118]	valid_0's multi_logloss: 1.16759
# [119]	valid_0's multi_logloss: 1.16588
# [120]	valid_0's multi_logloss: 1.16387
# [121]	valid_0's multi_logloss: 1.16241
# [122]	valid_0's multi_logloss: 1.16106
# [123]	valid_0's multi_logloss: 1.15929
# [124]	valid_0's multi_logloss: 1.15719
# [125]	valid_0's multi_logloss: 1.15545
# [126]	valid_0's multi_logloss: 1.15373
# [127]	valid_0's multi_logloss: 1.15203
# [128]	valid_0's multi_logloss: 1.15012
# [129]	valid_0's multi_logloss: 1.14857
# [130]	valid_0's multi_logloss: 1.14682
# [131]	valid_0's multi_logloss: 1.14542
# [132]	valid_0's multi_logloss: 1.14431
# [133]	valid_0's multi_logloss: 1.14273
# [134]	valid_0's multi_logloss: 1.14101
# [135]	valid_0's multi_logloss: 1.13959
# [136]	valid_0's multi_logloss: 1.13836
# [137]	valid_0's multi_logloss: 1.1366
# [138]	valid_0's multi_logloss: 1.13478
# [139]	valid_0's multi_logloss: 1.13332
# [140]	valid_0's multi_logloss: 1.13163
# [141]	valid_0's multi_logloss: 1.13005
# [142]	valid_0's multi_logloss: 1.12852
# [143]	valid_0's multi_logloss: 1.12721
# [144]	valid_0's multi_logloss: 1.12543
# [145]	valid_0's multi_logloss: 1.12399
# [146]	valid_0's multi_logloss: 1.12246
# [147]	valid_0's multi_logloss: 1.12109
# [148]	valid_0's multi_logloss: 1.12005
# [149]	valid_0's multi_logloss: 1.1183
# [150]	valid_0's multi_logloss: 1.11688
# [151]	valid_0's multi_logloss: 1.11573
# [152]	valid_0's multi_logloss: 1.1143
# [153]	valid_0's multi_logloss: 1.11303
# [154]	valid_0's multi_logloss: 1.11166
# [155]	valid_0's multi_logloss: 1.11005
# [156]	valid_0's multi_logloss: 1.10832
# [157]	valid_0's multi_logloss: 1.10742
# [158]	valid_0's multi_logloss: 1.10644
# [159]	valid_0's multi_logloss: 1.10512
# [160]	valid_0's multi_logloss: 1.10381
# [161]	valid_0's multi_logloss: 1.10226
# [162]	valid_0's multi_logloss: 1.10109
# [163]	valid_0's multi_logloss: 1.09958
# [164]	valid_0's multi_logloss: 1.09827
# [165]	valid_0's multi_logloss: 1.09737
# [166]	valid_0's multi_logloss: 1.09624
# [167]	valid_0's multi_logloss: 1.09528
# [168]	valid_0's multi_logloss: 1.09405
# [169]	valid_0's multi_logloss: 1.09272
# [170]	valid_0's multi_logloss: 1.09164
# [171]	valid_0's multi_logloss: 1.09027
# [172]	valid_0's multi_logloss: 1.08907
# [173]	valid_0's multi_logloss: 1.08765
# [174]	valid_0's multi_logloss: 1.08657
# [175]	valid_0's multi_logloss: 1.08538
# [176]	valid_0's multi_logloss: 1.08416
# [177]	valid_0's multi_logloss: 1.08309
# [178]	valid_0's multi_logloss: 1.08204
# [179]	valid_0's multi_logloss: 1.0807
# [180]	valid_0's multi_logloss: 1.07968
# [181]	valid_0's multi_logloss: 1.07857
# [182]	valid_0's multi_logloss: 1.07752
# [183]	valid_0's multi_logloss: 1.07663
# [184]	valid_0's multi_logloss: 1.07558
# [185]	valid_0's multi_logloss: 1.0741
# [186]	valid_0's multi_logloss: 1.07283
# [187]	valid_0's multi_logloss: 1.0717
# [188]	valid_0's multi_logloss: 1.07044
# [189]	valid_0's multi_logloss: 1.06936
# [190]	valid_0's multi_logloss: 1.0687
# [191]	valid_0's multi_logloss: 1.06785
# [192]	valid_0's multi_logloss: 1.06707
# [193]	valid_0's multi_logloss: 1.06611
# [194]	valid_0's multi_logloss: 1.06485
# [195]	valid_0's multi_logloss: 1.0636
# [196]	valid_0's multi_logloss: 1.06221
# [197]	valid_0's multi_logloss: 1.06125
# [198]	valid_0's multi_logloss: 1.06029
# [199]	valid_0's multi_logloss: 1.05939
# [200]	valid_0's multi_logloss: 1.05859
# [201]	valid_0's multi_logloss: 1.05786
# [202]	valid_0's multi_logloss: 1.05676
# [203]	valid_0's multi_logloss: 1.05575
# [204]	valid_0's multi_logloss: 1.05481
# [205]	valid_0's multi_logloss: 1.0536
# [206]	valid_0's multi_logloss: 1.05258
# [207]	valid_0's multi_logloss: 1.0517
# [208]	valid_0's multi_logloss: 1.05083
# [209]	valid_0's multi_logloss: 1.04962
# [210]	valid_0's multi_logloss: 1.04851
# [211]	valid_0's multi_logloss: 1.04783
# [212]	valid_0's multi_logloss: 1.04705
# [213]	valid_0's multi_logloss: 1.04611
# [214]	valid_0's multi_logloss: 1.04526
# [215]	valid_0's multi_logloss: 1.0442
# [216]	valid_0's multi_logloss: 1.0431
# [217]	valid_0's multi_logloss: 1.04223
# [218]	valid_0's multi_logloss: 1.04139
# [219]	valid_0's multi_logloss: 1.04054
# [220]	valid_0's multi_logloss: 1.03964
# [221]	valid_0's multi_logloss: 1.03873
# [222]	valid_0's multi_logloss: 1.03775
# [223]	valid_0's multi_logloss: 1.03695
# [224]	valid_0's multi_logloss: 1.03629
# [225]	valid_0's multi_logloss: 1.03543
# [226]	valid_0's multi_logloss: 1.03443
# [227]	valid_0's multi_logloss: 1.03365
# [228]	valid_0's multi_logloss: 1.03272
# [229]	valid_0's multi_logloss: 1.03186
# [230]	valid_0's multi_logloss: 1.03118
# [231]	valid_0's multi_logloss: 1.03041
# [232]	valid_0's multi_logloss: 1.02974
# [233]	valid_0's multi_logloss: 1.02893
# [234]	valid_0's multi_logloss: 1.02841
# [235]	valid_0's multi_logloss: 1.02728
# [236]	valid_0's multi_logloss: 1.02677
# [237]	valid_0's multi_logloss: 1.02595
# [238]	valid_0's multi_logloss: 1.02495
# [239]	valid_0's multi_logloss: 1.02414
# [240]	valid_0's multi_logloss: 1.02326
# [241]	valid_0's multi_logloss: 1.02225
# [242]	valid_0's multi_logloss: 1.02138
# [243]	valid_0's multi_logloss: 1.02055
# [244]	valid_0's multi_logloss: 1.01957
# [245]	valid_0's multi_logloss: 1.01884
# [246]	valid_0's multi_logloss: 1.01815
# [247]	valid_0's multi_logloss: 1.0171
# [248]	valid_0's multi_logloss: 1.01647
# [249]	valid_0's multi_logloss: 1.01588
# [250]	valid_0's multi_logloss: 1.01482
# [251]	valid_0's multi_logloss: 1.01409
# [252]	valid_0's multi_logloss: 1.01313
# [253]	valid_0's multi_logloss: 1.01249
# [254]	valid_0's multi_logloss: 1.01136
# [255]	valid_0's multi_logloss: 1.01094
# [256]	valid_0's multi_logloss: 1.01013
# [257]	valid_0's multi_logloss: 1.00942
# [258]	valid_0's multi_logloss: 1.00885
# [259]	valid_0's multi_logloss: 1.00799
# [260]	valid_0's multi_logloss: 1.0072
# [261]	valid_0's multi_logloss: 1.00625
# [262]	valid_0's multi_logloss: 1.00546
# [263]	valid_0's multi_logloss: 1.00475
# [264]	valid_0's multi_logloss: 1.00392
# [265]	valid_0's multi_logloss: 1.00331
# [266]	valid_0's multi_logloss: 1.00244
# [267]	valid_0's multi_logloss: 1.00157
# [268]	valid_0's multi_logloss: 1.00065
# [269]	valid_0's multi_logloss: 1
# [270]	valid_0's multi_logloss: 0.999283
# [271]	valid_0's multi_logloss: 0.998559
# [272]	valid_0's multi_logloss: 0.998134
# [273]	valid_0's multi_logloss: 0.99772
# [274]	valid_0's multi_logloss: 0.99711
# [275]	valid_0's multi_logloss: 0.996578
# [276]	valid_0's multi_logloss: 0.996079
# [277]	valid_0's multi_logloss: 0.995349
# [278]	valid_0's multi_logloss: 0.994631
# [279]	valid_0's multi_logloss: 0.994246
# [280]	valid_0's multi_logloss: 0.993305
# [281]	valid_0's multi_logloss: 0.992806
# [282]	valid_0's multi_logloss: 0.992051
# [283]	valid_0's multi_logloss: 0.991464
# [284]	valid_0's multi_logloss: 0.990575
# [285]	valid_0's multi_logloss: 0.989877
# [286]	valid_0's multi_logloss: 0.989105
# [287]	valid_0's multi_logloss: 0.988569
# [288]	valid_0's multi_logloss: 0.987887
# [289]	valid_0's multi_logloss: 0.987364
# [290]	valid_0's multi_logloss: 0.986883
# [291]	valid_0's multi_logloss: 0.986184
# [292]	valid_0's multi_logloss: 0.985417
# [293]	valid_0's multi_logloss: 0.98482
# [294]	valid_0's multi_logloss: 0.984365
# [295]	valid_0's multi_logloss: 0.98367
# [296]	valid_0's multi_logloss: 0.983287
# [297]	valid_0's multi_logloss: 0.982813
# [298]	valid_0's multi_logloss: 0.982151
# [299]	valid_0's multi_logloss: 0.981489
# [300]	valid_0's multi_logloss: 0.981062
# [301]	valid_0's multi_logloss: 0.980472
# [302]	valid_0's multi_logloss: 0.979799
# [303]	valid_0's multi_logloss: 0.979326
# [304]	valid_0's multi_logloss: 0.978926
# [305]	valid_0's multi_logloss: 0.978418
# [306]	valid_0's multi_logloss: 0.978048
# [307]	valid_0's multi_logloss: 0.977456
# [308]	valid_0's multi_logloss: 0.977023
# [309]	valid_0's multi_logloss: 0.97658
# [310]	valid_0's multi_logloss: 0.976044
# [311]	valid_0's multi_logloss: 0.975534
# [312]	valid_0's multi_logloss: 0.974631
# [313]	valid_0's multi_logloss: 0.97422
# [314]	valid_0's multi_logloss: 0.973458
# [315]	valid_0's multi_logloss: 0.9731
# [316]	valid_0's multi_logloss: 0.972582
# [317]	valid_0's multi_logloss: 0.972206
# [318]	valid_0's multi_logloss: 0.97176
# [319]	valid_0's multi_logloss: 0.97153
# [320]	valid_0's multi_logloss: 0.971053
# [321]	valid_0's multi_logloss: 0.970565
# [322]	valid_0's multi_logloss: 0.969881
# [323]	valid_0's multi_logloss: 0.969323
# [324]	valid_0's multi_logloss: 0.9688
# [325]	valid_0's multi_logloss: 0.968469
# [326]	valid_0's multi_logloss: 0.967959
# [327]	valid_0's multi_logloss: 0.967539
# [328]	valid_0's multi_logloss: 0.966966
# [329]	valid_0's multi_logloss: 0.96667
# [330]	valid_0's multi_logloss: 0.966217
# [331]	valid_0's multi_logloss: 0.965673
# [332]	valid_0's multi_logloss: 0.965258
# [333]	valid_0's multi_logloss: 0.96469
# [334]	valid_0's multi_logloss: 0.964425
# [335]	valid_0's multi_logloss: 0.963959
# [336]	valid_0's multi_logloss: 0.963544
# [337]	valid_0's multi_logloss: 0.963237
# [338]	valid_0's multi_logloss: 0.962515
# [339]	valid_0's multi_logloss: 0.961851
# [340]	valid_0's multi_logloss: 0.961268
# [341]	valid_0's multi_logloss: 0.960897
# [342]	valid_0's multi_logloss: 0.960451
# [343]	valid_0's multi_logloss: 0.960149
# [344]	valid_0's multi_logloss: 0.95966
# [345]	valid_0's multi_logloss: 0.95907
# [346]	valid_0's multi_logloss: 0.958585
# [347]	valid_0's multi_logloss: 0.958075
# [348]	valid_0's multi_logloss: 0.957686
# [349]	valid_0's multi_logloss: 0.957001
# [350]	valid_0's multi_logloss: 0.95646
# [351]	valid_0's multi_logloss: 0.956053
# [352]	valid_0's multi_logloss: 0.955456
# [353]	valid_0's multi_logloss: 0.954953
# [354]	valid_0's multi_logloss: 0.954401
# [355]	valid_0's multi_logloss: 0.953872
# [356]	valid_0's multi_logloss: 0.953502
# [357]	valid_0's multi_logloss: 0.952946
# [358]	valid_0's multi_logloss: 0.952622
# [359]	valid_0's multi_logloss: 0.952098
# [360]	valid_0's multi_logloss: 0.951746
# [361]	valid_0's multi_logloss: 0.951252
# [362]	valid_0's multi_logloss: 0.950922
# [363]	valid_0's multi_logloss: 0.950579
# [364]	valid_0's multi_logloss: 0.950071
# [365]	valid_0's multi_logloss: 0.949623
# [366]	valid_0's multi_logloss: 0.94929
# [367]	valid_0's multi_logloss: 0.948954
# [368]	valid_0's multi_logloss: 0.948612
# [369]	valid_0's multi_logloss: 0.9481
# [370]	valid_0's multi_logloss: 0.94775
# [371]	valid_0's multi_logloss: 0.947489
# [372]	valid_0's multi_logloss: 0.946966
# [373]	valid_0's multi_logloss: 0.946629
# [374]	valid_0's multi_logloss: 0.946346
# [375]	valid_0's multi_logloss: 0.946182
# [376]	valid_0's multi_logloss: 0.945559
# [377]	valid_0's multi_logloss: 0.945131
# [378]	valid_0's multi_logloss: 0.944724
# [379]	valid_0's multi_logloss: 0.944392
# [380]	valid_0's multi_logloss: 0.944121
# [381]	valid_0's multi_logloss: 0.943859
# [382]	valid_0's multi_logloss: 0.943534
# [383]	valid_0's multi_logloss: 0.943087
# [384]	valid_0's multi_logloss: 0.942771
# [385]	valid_0's multi_logloss: 0.942301
# [386]	valid_0's multi_logloss: 0.941985
# [387]	valid_0's multi_logloss: 0.941668
# [388]	valid_0's multi_logloss: 0.941287
# [389]	valid_0's multi_logloss: 0.940609
# [390]	valid_0's multi_logloss: 0.940127
# [391]	valid_0's multi_logloss: 0.939757
# [392]	valid_0's multi_logloss: 0.939783
# [393]	valid_0's multi_logloss: 0.939256
# [394]	valid_0's multi_logloss: 0.938905
# [395]	valid_0's multi_logloss: 0.938423
# [396]	valid_0's multi_logloss: 0.938114
# [397]	valid_0's multi_logloss: 0.937889
# [398]	valid_0's multi_logloss: 0.937745
# [399]	valid_0's multi_logloss: 0.937584
# [400]	valid_0's multi_logloss: 0.937291
# [401]	valid_0's multi_logloss: 0.936942
# [402]	valid_0's multi_logloss: 0.936467
# [403]	valid_0's multi_logloss: 0.936036
# [404]	valid_0's multi_logloss: 0.935758
# [405]	valid_0's multi_logloss: 0.935377
# [406]	valid_0's multi_logloss: 0.935125
# [407]	valid_0's multi_logloss: 0.934797
# [408]	valid_0's multi_logloss: 0.934549
# [409]	valid_0's multi_logloss: 0.934327
# [410]	valid_0's multi_logloss: 0.934018
# [411]	valid_0's multi_logloss: 0.933837
# [412]	valid_0's multi_logloss: 0.933331
# [413]	valid_0's multi_logloss: 0.933102
# [414]	valid_0's multi_logloss: 0.932654
# [415]	valid_0's multi_logloss: 0.93238
# [416]	valid_0's multi_logloss: 0.932254
# [417]	valid_0's multi_logloss: 0.931874
# [418]	valid_0's multi_logloss: 0.931333
# [419]	valid_0's multi_logloss: 0.931125
# [420]	valid_0's multi_logloss: 0.930795
# [421]	valid_0's multi_logloss: 0.930554
# [422]	valid_0's multi_logloss: 0.930256
# [423]	valid_0's multi_logloss: 0.930143
# [424]	valid_0's multi_logloss: 0.929895
# [425]	valid_0's multi_logloss: 0.929632
# [426]	valid_0's multi_logloss: 0.929269
# [427]	valid_0's multi_logloss: 0.929
# [428]	valid_0's multi_logloss: 0.928762
# [429]	valid_0's multi_logloss: 0.928419
# [430]	valid_0's multi_logloss: 0.928062
# [431]	valid_0's multi_logloss: 0.92764
# [432]	valid_0's multi_logloss: 0.927185
# [433]	valid_0's multi_logloss: 0.926956
# [434]	valid_0's multi_logloss: 0.926638
# [435]	valid_0's multi_logloss: 0.92614
# [436]	valid_0's multi_logloss: 0.925918
# [437]	valid_0's multi_logloss: 0.925618
# [438]	valid_0's multi_logloss: 0.925235
# [439]	valid_0's multi_logloss: 0.924667
# [440]	valid_0's multi_logloss: 0.924689
# [441]	valid_0's multi_logloss: 0.924514
# [442]	valid_0's multi_logloss: 0.924225
# [443]	valid_0's multi_logloss: 0.923707
# [444]	valid_0's multi_logloss: 0.923365
# [445]	valid_0's multi_logloss: 0.923152
# [446]	valid_0's multi_logloss: 0.92282
# [447]	valid_0's multi_logloss: 0.922332
# [448]	valid_0's multi_logloss: 0.922121
# [449]	valid_0's multi_logloss: 0.921853
# [450]	valid_0's multi_logloss: 0.921454
# [451]	valid_0's multi_logloss: 0.920994
# [452]	valid_0's multi_logloss: 0.920686
# [453]	valid_0's multi_logloss: 0.920308
# [454]	valid_0's multi_logloss: 0.920154
# [455]	valid_0's multi_logloss: 0.920066
# [456]	valid_0's multi_logloss: 0.919681
# [457]	valid_0's multi_logloss: 0.919377
# [458]	valid_0's multi_logloss: 0.919231
# [459]	valid_0's multi_logloss: 0.918859
# [460]	valid_0's multi_logloss: 0.918785
# [461]	valid_0's multi_logloss: 0.918635
# [462]	valid_0's multi_logloss: 0.918382
# [463]	valid_0's multi_logloss: 0.918217
# [464]	valid_0's multi_logloss: 0.918023
# [465]	valid_0's multi_logloss: 0.918018
# [466]	valid_0's multi_logloss: 0.9179
# [467]	valid_0's multi_logloss: 0.917485
# [468]	valid_0's multi_logloss: 0.917136
# [469]	valid_0's multi_logloss: 0.916932
# [470]	valid_0's multi_logloss: 0.916747
# [471]	valid_0's multi_logloss: 0.916423
# [472]	valid_0's multi_logloss: 0.916276
# [473]	valid_0's multi_logloss: 0.916304
# [474]	valid_0's multi_logloss: 0.916046
# [475]	valid_0's multi_logloss: 0.915773
# [476]	valid_0's multi_logloss: 0.91554
# [477]	valid_0's multi_logloss: 0.915303
# [478]	valid_0's multi_logloss: 0.915016
# [479]	valid_0's multi_logloss: 0.914766
# [480]	valid_0's multi_logloss: 0.914623
# [481]	valid_0's multi_logloss: 0.91448
# [482]	valid_0's multi_logloss: 0.913842
# [483]	valid_0's multi_logloss: 0.913496
# [484]	valid_0's multi_logloss: 0.913334
# [485]	valid_0's multi_logloss: 0.913101
# [486]	valid_0's multi_logloss: 0.912717
# [487]	valid_0's multi_logloss: 0.912574
# [488]	valid_0's multi_logloss: 0.912371
# [489]	valid_0's multi_logloss: 0.912229
# [490]	valid_0's multi_logloss: 0.912094
# [491]	valid_0's multi_logloss: 0.912018
# [492]	valid_0's multi_logloss: 0.911873
# [493]	valid_0's multi_logloss: 0.911626
# [494]	valid_0's multi_logloss: 0.911637
# [495]	valid_0's multi_logloss: 0.911279
# [496]	valid_0's multi_logloss: 0.911029
# [497]	valid_0's multi_logloss: 0.910695
# [498]	valid_0's multi_logloss: 0.91053
# [499]	valid_0's multi_logloss: 0.91014
# [500]	valid_0's multi_logloss: 0.909971
# [501]	valid_0's multi_logloss: 0.909864
# [502]	valid_0's multi_logloss: 0.909703
# [503]	valid_0's multi_logloss: 0.90953
# [504]	valid_0's multi_logloss: 0.90936
# [505]	valid_0's multi_logloss: 0.909061
# [506]	valid_0's multi_logloss: 0.90885
# [507]	valid_0's multi_logloss: 0.908866
# [508]	valid_0's multi_logloss: 0.908648
# [509]	valid_0's multi_logloss: 0.908454
# [510]	valid_0's multi_logloss: 0.908314
# [511]	valid_0's multi_logloss: 0.908181
# [512]	valid_0's multi_logloss: 0.907895
# [513]	valid_0's multi_logloss: 0.907673
# [514]	valid_0's multi_logloss: 0.907314
# [515]	valid_0's multi_logloss: 0.907117
# [516]	valid_0's multi_logloss: 0.906934
# [517]	valid_0's multi_logloss: 0.90672
# [518]	valid_0's multi_logloss: 0.906646
# [519]	valid_0's multi_logloss: 0.906537
# [520]	valid_0's multi_logloss: 0.906477
# [521]	valid_0's multi_logloss: 0.906297
# [522]	valid_0's multi_logloss: 0.906112
# [523]	valid_0's multi_logloss: 0.906
# [524]	valid_0's multi_logloss: 0.906013
# [525]	valid_0's multi_logloss: 0.905734
# [526]	valid_0's multi_logloss: 0.90561
# [527]	valid_0's multi_logloss: 0.90523
# [528]	valid_0's multi_logloss: 0.90478
# [529]	valid_0's multi_logloss: 0.904485
# [530]	valid_0's multi_logloss: 0.904196
# [531]	valid_0's multi_logloss: 0.904215
# [532]	valid_0's multi_logloss: 0.903946
# [533]	valid_0's multi_logloss: 0.90388
# [534]	valid_0's multi_logloss: 0.903725
# [535]	valid_0's multi_logloss: 0.903702
# [536]	valid_0's multi_logloss: 0.903451
# [537]	valid_0's multi_logloss: 0.903331
# [538]	valid_0's multi_logloss: 0.903183
# [539]	valid_0's multi_logloss: 0.90306
# [540]	valid_0's multi_logloss: 0.902892
# [541]	valid_0's multi_logloss: 0.902638
# [542]	valid_0's multi_logloss: 0.902448
# [543]	valid_0's multi_logloss: 0.90235
# [544]	valid_0's multi_logloss: 0.902236
# [545]	valid_0's multi_logloss: 0.902011
# [546]	valid_0's multi_logloss: 0.901872
# [547]	valid_0's multi_logloss: 0.901473
# [548]	valid_0's multi_logloss: 0.901242
# [549]	valid_0's multi_logloss: 0.901148
# [550]	valid_0's multi_logloss: 0.900839
# [551]	valid_0's multi_logloss: 0.900837
# [552]	valid_0's multi_logloss: 0.90063
# [553]	valid_0's multi_logloss: 0.900459
# [554]	valid_0's multi_logloss: 0.900281
# [555]	valid_0's multi_logloss: 0.900091
# [556]	valid_0's multi_logloss: 0.899963
# [557]	valid_0's multi_logloss: 0.89975
# [558]	valid_0's multi_logloss: 0.899853
# [559]	valid_0's multi_logloss: 0.899907
# [560]	valid_0's multi_logloss: 0.899823
# [561]	valid_0's multi_logloss: 0.899879
# [562]	valid_0's multi_logloss: 0.899583
# [563]	valid_0's multi_logloss: 0.899582
# [564]	valid_0's multi_logloss: 0.899558
# [565]	valid_0's multi_logloss: 0.899371
# [566]	valid_0's multi_logloss: 0.899222
# [567]	valid_0's multi_logloss: 0.899368
# [568]	valid_0's multi_logloss: 0.899223
# [569]	valid_0's multi_logloss: 0.899252
# [570]	valid_0's multi_logloss: 0.899147
# [571]	valid_0's multi_logloss: 0.898985
# [572]	valid_0's multi_logloss: 0.898829
# [573]	valid_0's multi_logloss: 0.898514
# [574]	valid_0's multi_logloss: 0.898365
# [575]	valid_0's multi_logloss: 0.898101
# [576]	valid_0's multi_logloss: 0.897783
# [577]	valid_0's multi_logloss: 0.897477
# [578]	valid_0's multi_logloss: 0.897246
# [579]	valid_0's multi_logloss: 0.896893
# [580]	valid_0's multi_logloss: 0.896668
# [581]	valid_0's multi_logloss: 0.89664
# [582]	valid_0's multi_logloss: 0.896509
# [583]	valid_0's multi_logloss: 0.896405
# [584]	valid_0's multi_logloss: 0.896239
# [585]	valid_0's multi_logloss: 0.896226
# [586]	valid_0's multi_logloss: 0.896006
# [587]	valid_0's multi_logloss: 0.895757
# [588]	valid_0's multi_logloss: 0.895595
# [589]	valid_0's multi_logloss: 0.895638
# [590]	valid_0's multi_logloss: 0.895642
# [591]	valid_0's multi_logloss: 0.895383
# [592]	valid_0's multi_logloss: 0.895235
# [593]	valid_0's multi_logloss: 0.89503
# [594]	valid_0's multi_logloss: 0.894799
# [595]	valid_0's multi_logloss: 0.894674
# [596]	valid_0's multi_logloss: 0.89475
# [597]	valid_0's multi_logloss: 0.894553
# [598]	valid_0's multi_logloss: 0.894378
# [599]	valid_0's multi_logloss: 0.894171
# [600]	valid_0's multi_logloss: 0.893852
# [601]	valid_0's multi_logloss: 0.893694
# [602]	valid_0's multi_logloss: 0.893573
# [603]	valid_0's multi_logloss: 0.893423
# [604]	valid_0's multi_logloss: 0.893301
# [605]	valid_0's multi_logloss: 0.893173
# [606]	valid_0's multi_logloss: 0.893204
# [607]	valid_0's multi_logloss: 0.892972
# [608]	valid_0's multi_logloss: 0.892712
# [609]	valid_0's multi_logloss: 0.892615
# [610]	valid_0's multi_logloss: 0.892632
# [611]	valid_0's multi_logloss: 0.892347
# [612]	valid_0's multi_logloss: 0.892235
# [613]	valid_0's multi_logloss: 0.892071
# [614]	valid_0's multi_logloss: 0.891896
# [615]	valid_0's multi_logloss: 0.89184
# [616]	valid_0's multi_logloss: 0.891914
# [617]	valid_0's multi_logloss: 0.891726
# [618]	valid_0's multi_logloss: 0.891764
# [619]	valid_0's multi_logloss: 0.891414
# [620]	valid_0's multi_logloss: 0.891436
# [621]	valid_0's multi_logloss: 0.891171
# [622]	valid_0's multi_logloss: 0.890941
# [623]	valid_0's multi_logloss: 0.890896
# [624]	valid_0's multi_logloss: 0.890999
# [625]	valid_0's multi_logloss: 0.890863
# [626]	valid_0's multi_logloss: 0.89099
# [627]	valid_0's multi_logloss: 0.890806
# [628]	valid_0's multi_logloss: 0.890866
# [629]	valid_0's multi_logloss: 0.890709
# [630]	valid_0's multi_logloss: 0.89073
# [631]	valid_0's multi_logloss: 0.890564
# [632]	valid_0's multi_logloss: 0.890398
# [633]	valid_0's multi_logloss: 0.890336
# [634]	valid_0's multi_logloss: 0.890216
# [635]	valid_0's multi_logloss: 0.890329
# [636]	valid_0's multi_logloss: 0.890326
# [637]	valid_0's multi_logloss: 0.890329
# [638]	valid_0's multi_logloss: 0.890263
# [639]	valid_0's multi_logloss: 0.890446
# [640]	valid_0's multi_logloss: 0.89021
# [641]	valid_0's multi_logloss: 0.890009
# [642]	valid_0's multi_logloss: 0.890063
# [643]	valid_0's multi_logloss: 0.889718
# [644]	valid_0's multi_logloss: 0.88975
# [645]	valid_0's multi_logloss: 0.889717
# [646]	valid_0's multi_logloss: 0.88974
# [647]	valid_0's multi_logloss: 0.889938
# [648]	valid_0's multi_logloss: 0.889877
# [649]	valid_0's multi_logloss: 0.889783
# [650]	valid_0's multi_logloss: 0.889865
# [651]	valid_0's multi_logloss: 0.889694
# [652]	valid_0's multi_logloss: 0.889502
# [653]	valid_0's multi_logloss: 0.889428
# [654]	valid_0's multi_logloss: 0.889499
# [655]	valid_0's multi_logloss: 0.889389
# [656]	valid_0's multi_logloss: 0.889113
# [657]	valid_0's multi_logloss: 0.888976
# [658]	valid_0's multi_logloss: 0.88893
# [659]	valid_0's multi_logloss: 0.888965
# [660]	valid_0's multi_logloss: 0.888684
# [661]	valid_0's multi_logloss: 0.888684
# [662]	valid_0's multi_logloss: 0.888574
# [663]	valid_0's multi_logloss: 0.888517
# [664]	valid_0's multi_logloss: 0.888422
# [665]	valid_0's multi_logloss: 0.888489
# [666]	valid_0's multi_logloss: 0.888426
# [667]	valid_0's multi_logloss: 0.888326
# [668]	valid_0's multi_logloss: 0.888287
# [669]	valid_0's multi_logloss: 0.88813
# [670]	valid_0's multi_logloss: 0.88812
# [671]	valid_0's multi_logloss: 0.887878
# [672]	valid_0's multi_logloss: 0.887731
# [673]	valid_0's multi_logloss: 0.887628
# [674]	valid_0's multi_logloss: 0.887585
# [675]	valid_0's multi_logloss: 0.887637
# [676]	valid_0's multi_logloss: 0.887604
# [677]	valid_0's multi_logloss: 0.887586
# [678]	valid_0's multi_logloss: 0.887565
# [679]	valid_0's multi_logloss: 0.88785
# [680]	valid_0's multi_logloss: 0.888099
# [681]	valid_0's multi_logloss: 0.888161
# [682]	valid_0's multi_logloss: 0.888226
# [683]	valid_0's multi_logloss: 0.888143
# [684]	valid_0's multi_logloss: 0.888068
# [685]	valid_0's multi_logloss: 0.888163
# [686]	valid_0's multi_logloss: 0.887827
# [687]	valid_0's multi_logloss: 0.887632
# [688]	valid_0's multi_logloss: 0.887685
# [689]	valid_0's multi_logloss: 0.88757
# [690]	valid_0's multi_logloss: 0.88748
# [691]	valid_0's multi_logloss: 0.88735
# [692]	valid_0's multi_logloss: 0.887152
# [693]	valid_0's multi_logloss: 0.887064
# [694]	valid_0's multi_logloss: 0.887099
# [695]	valid_0's multi_logloss: 0.887031
# [696]	valid_0's multi_logloss: 0.887062
# [697]	valid_0's multi_logloss: 0.88695
# [698]	valid_0's multi_logloss: 0.887109
# [699]	valid_0's multi_logloss: 0.887159
# [700]	valid_0's multi_logloss: 0.887289
# [701]	valid_0's multi_logloss: 0.887233
# [702]	valid_0's multi_logloss: 0.88718
# [703]	valid_0's multi_logloss: 0.887061
# [704]	valid_0's multi_logloss: 0.887046
# [705]	valid_0's multi_logloss: 0.88707
# [706]	valid_0's multi_logloss: 0.886934
# [707]	valid_0's multi_logloss: 0.88697
# [708]	valid_0's multi_logloss: 0.887031
# [709]	valid_0's multi_logloss: 0.886973
# [710]	valid_0's multi_logloss: 0.88682
# [711]	valid_0's multi_logloss: 0.886912
# [712]	valid_0's multi_logloss: 0.887
# [713]	valid_0's multi_logloss: 0.887067
# [714]	valid_0's multi_logloss: 0.886988
# [715]	valid_0's multi_logloss: 0.886867
# [716]	valid_0's multi_logloss: 0.886652
# [717]	valid_0's multi_logloss: 0.886486
# [718]	valid_0's multi_logloss: 0.886293
# [719]	valid_0's multi_logloss: 0.88627
# [720]	valid_0's multi_logloss: 0.886189
# [721]	valid_0's multi_logloss: 0.886162
# [722]	valid_0's multi_logloss: 0.886188
# [723]	valid_0's multi_logloss: 0.886245
# [724]	valid_0's multi_logloss: 0.886092
# [725]	valid_0's multi_logloss: 0.88614
# [726]	valid_0's multi_logloss: 0.8862
# [727]	valid_0's multi_logloss: 0.886262
# [728]	valid_0's multi_logloss: 0.886236
# [729]	valid_0's multi_logloss: 0.886103
# [730]	valid_0's multi_logloss: 0.88599
# [731]	valid_0's multi_logloss: 0.886096
# [732]	valid_0's multi_logloss: 0.886158
# [733]	valid_0's multi_logloss: 0.886046
# [734]	valid_0's multi_logloss: 0.886161
# [735]	valid_0's multi_logloss: 0.886196
# [736]	valid_0's multi_logloss: 0.885762
# [737]	valid_0's multi_logloss: 0.885658
# [738]	valid_0's multi_logloss: 0.885905
# [739]	valid_0's multi_logloss: 0.886045
# [740]	valid_0's multi_logloss: 0.885936
# [741]	valid_0's multi_logloss: 0.885949
# [742]	valid_0's multi_logloss: 0.885949
# [743]	valid_0's multi_logloss: 0.885932
# [744]	valid_0's multi_logloss: 0.885864
# [745]	valid_0's multi_logloss: 0.885917
# [746]	valid_0's multi_logloss: 0.886062
# [747]	valid_0's multi_logloss: 0.885817
# [748]	valid_0's multi_logloss: 0.885717
# [749]	valid_0's multi_logloss: 0.8858
# [750]	valid_0's multi_logloss: 0.885756
# [751]	valid_0's multi_logloss: 0.885772
# [752]	valid_0's multi_logloss: 0.885422
# [753]	valid_0's multi_logloss: 0.885649
# [754]	valid_0's multi_logloss: 0.885719
# [755]	valid_0's multi_logloss: 0.885716
# [756]	valid_0's multi_logloss: 0.885596
# [757]	valid_0's multi_logloss: 0.885692
# [758]	valid_0's multi_logloss: 0.885725
# [759]	valid_0's multi_logloss: 0.885624
# [760]	valid_0's multi_logloss: 0.885601
# [761]	valid_0's multi_logloss: 0.885666
# [762]	valid_0's multi_logloss: 0.885755
# [763]	valid_0's multi_logloss: 0.885829
# [764]	valid_0's multi_logloss: 0.885722
# [765]	valid_0's multi_logloss: 0.885863
# [766]	valid_0's multi_logloss: 0.885884
# [767]	valid_0's multi_logloss: 0.885807
# [768]	valid_0's multi_logloss: 0.885846
# [769]	valid_0's multi_logloss: 0.885912
# [770]	valid_0's multi_logloss: 0.88601
# [771]	valid_0's multi_logloss: 0.886014
# [772]	valid_0's multi_logloss: 0.886015
# Early stopping, best iteration is:
# [752]	valid_0's multi_logloss: 0.885422
# F1 Score for class 0: 0.8499999999999999
# F1 Score for class 1: 0.9141856392294221
# F1 Score for class 2: 0.7584187408491948
# F1 Score for class 3: 0.9468354430379746
# F1 Score for class 4: 0.8917748917748918
# F1 Score for class 5: 0.7906976744186047
# F1 Score for class 6: 0.5890603085553997
# F1 Score for class 7: 0.8806584362139916
# F1 Score for class 8: 0.5301204819277109
# F1 Score for class 9: 0.6303939962476548
# F1 Score for class 10: 0.8584202682563339
# F1 Score for class 11: 0.7520000000000001
# F1 Score for class 12: 0.6963350785340314
# F1 Score for class 13: 0.7614147909967846
# F1 Score for class 14: 0.9377483443708609
# F1 Score for class 15: 0.7375271149674619
# F1 Score for class 16: 0.6778846153846154
# F1 Score for class 17: 0.7191011235955057
# F1 Score for class 18: 0.6174168297455969
# F1 Score for class 19: 0.5906040268456375
# F1 Score for class 20: 0.9252669039145908
# F1 Score for class 21: 0.8565891472868218
# F1 Score for class 22: 0.5873015873015873
# F1 Score for class 23: 0.8606060606060606
# F1 Score for class 24: 0.744186046511628
# F1 Score for class 25: 0.9083155650319829
# Overall F1 Score (Macro): 0.769725504446321
# (31899, 28122) (7975, 28122)
# Seed: 0
# [1]	valid_0's multi_logloss: 2.69906
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's multi_logloss: 2.50445
# [3]	valid_0's multi_logloss: 2.36516
# [4]	valid_0's multi_logloss: 2.27964
# [5]	valid_0's multi_logloss: 2.19542
# [6]	valid_0's multi_logloss: 2.12675
# [7]	valid_0's multi_logloss: 2.06873
# [8]	valid_0's multi_logloss: 2.01114
# [9]	valid_0's multi_logloss: 1.96448
# [10]	valid_0's multi_logloss: 1.92192
# [11]	valid_0's multi_logloss: 1.88624
# [12]	valid_0's multi_logloss: 1.8507
# [13]	valid_0's multi_logloss: 1.82002
# [14]	valid_0's multi_logloss: 1.79234
# [15]	valid_0's multi_logloss: 1.76616
# [16]	valid_0's multi_logloss: 1.74152
# [17]	valid_0's multi_logloss: 1.71823
# [18]	valid_0's multi_logloss: 1.69593
# [19]	valid_0's multi_logloss: 1.67585
# [20]	valid_0's multi_logloss: 1.65727
# [21]	valid_0's multi_logloss: 1.64072
# [22]	valid_0's multi_logloss: 1.62269
# [23]	valid_0's multi_logloss: 1.60706
# [24]	valid_0's multi_logloss: 1.59238
# [25]	valid_0's multi_logloss: 1.57827
# [26]	valid_0's multi_logloss: 1.56511
# [27]	valid_0's multi_logloss: 1.55167
# [28]	valid_0's multi_logloss: 1.53961
# [29]	valid_0's multi_logloss: 1.52705
# [30]	valid_0's multi_logloss: 1.51541
# [31]	valid_0's multi_logloss: 1.50516
# [32]	valid_0's multi_logloss: 1.49425
# [33]	valid_0's multi_logloss: 1.48402
# [34]	valid_0's multi_logloss: 1.47503
# [35]	valid_0's multi_logloss: 1.46667
# [36]	valid_0's multi_logloss: 1.4581
# [37]	valid_0's multi_logloss: 1.45038
# [38]	valid_0's multi_logloss: 1.44262
# [39]	valid_0's multi_logloss: 1.435
# [40]	valid_0's multi_logloss: 1.42597
# [41]	valid_0's multi_logloss: 1.41933
# [42]	valid_0's multi_logloss: 1.41232
# [43]	valid_0's multi_logloss: 1.40544
# [44]	valid_0's multi_logloss: 1.39836
# [45]	valid_0's multi_logloss: 1.39226
# [46]	valid_0's multi_logloss: 1.38523
# [47]	valid_0's multi_logloss: 1.3792
# [48]	valid_0's multi_logloss: 1.37353
# [49]	valid_0's multi_logloss: 1.36799
# [50]	valid_0's multi_logloss: 1.36221
# [51]	valid_0's multi_logloss: 1.35695
# [52]	valid_0's multi_logloss: 1.35177
# [53]	valid_0's multi_logloss: 1.34705
# [54]	valid_0's multi_logloss: 1.3429
# [55]	valid_0's multi_logloss: 1.33843
# [56]	valid_0's multi_logloss: 1.33403
# [57]	valid_0's multi_logloss: 1.3299
# [58]	valid_0's multi_logloss: 1.32542
# [59]	valid_0's multi_logloss: 1.32173
# [60]	valid_0's multi_logloss: 1.31779
# [61]	valid_0's multi_logloss: 1.31394
# [62]	valid_0's multi_logloss: 1.31012
# [63]	valid_0's multi_logloss: 1.30643
# [64]	valid_0's multi_logloss: 1.30316
# [65]	valid_0's multi_logloss: 1.29891
# [66]	valid_0's multi_logloss: 1.29612
# [67]	valid_0's multi_logloss: 1.29226
# [68]	valid_0's multi_logloss: 1.2896
# [69]	valid_0's multi_logloss: 1.28611
# [70]	valid_0's multi_logloss: 1.28259
# [71]	valid_0's multi_logloss: 1.2795
# [72]	valid_0's multi_logloss: 1.27608
# [73]	valid_0's multi_logloss: 1.27313
# [74]	valid_0's multi_logloss: 1.27015
# [75]	valid_0's multi_logloss: 1.26756
# [76]	valid_0's multi_logloss: 1.26517
# [77]	valid_0's multi_logloss: 1.26208
# [78]	valid_0's multi_logloss: 1.25923
# [79]	valid_0's multi_logloss: 1.25649
# [80]	valid_0's multi_logloss: 1.25308
# [81]	valid_0's multi_logloss: 1.25024
# [82]	valid_0's multi_logloss: 1.24693
# [83]	valid_0's multi_logloss: 1.24448
# [84]	valid_0's multi_logloss: 1.24195
# [85]	valid_0's multi_logloss: 1.23854
# [86]	valid_0's multi_logloss: 1.2359
# [87]	valid_0's multi_logloss: 1.23321
# [88]	valid_0's multi_logloss: 1.23105
# [89]	valid_0's multi_logloss: 1.22846
# [90]	valid_0's multi_logloss: 1.22624
# [91]	valid_0's multi_logloss: 1.22331
# [92]	valid_0's multi_logloss: 1.22081
# [93]	valid_0's multi_logloss: 1.21851
# [94]	valid_0's multi_logloss: 1.21596
# [95]	valid_0's multi_logloss: 1.21371
# [96]	valid_0's multi_logloss: 1.21144
# [97]	valid_0's multi_logloss: 1.20952
# [98]	valid_0's multi_logloss: 1.20692
# [99]	valid_0's multi_logloss: 1.205
# [100]	valid_0's multi_logloss: 1.20275
# [101]	valid_0's multi_logloss: 1.20049
# [102]	valid_0's multi_logloss: 1.1983
# [103]	valid_0's multi_logloss: 1.19597
# [104]	valid_0's multi_logloss: 1.19368
# [105]	valid_0's multi_logloss: 1.1917
# [106]	valid_0's multi_logloss: 1.18982
# [107]	valid_0's multi_logloss: 1.18793
# [108]	valid_0's multi_logloss: 1.18608
# [109]	valid_0's multi_logloss: 1.18372
# [110]	valid_0's multi_logloss: 1.18193
# [111]	valid_0's multi_logloss: 1.18013
# [112]	valid_0's multi_logloss: 1.17828
# [113]	valid_0's multi_logloss: 1.1763
# [114]	valid_0's multi_logloss: 1.17455
# [115]	valid_0's multi_logloss: 1.17282
# [116]	valid_0's multi_logloss: 1.17062
# [117]	valid_0's multi_logloss: 1.16866
# [118]	valid_0's multi_logloss: 1.16652
# [119]	valid_0's multi_logloss: 1.16444
# [120]	valid_0's multi_logloss: 1.16307
# [121]	valid_0's multi_logloss: 1.16104
# [122]	valid_0's multi_logloss: 1.15946
# [123]	valid_0's multi_logloss: 1.15772
# [124]	valid_0's multi_logloss: 1.15582
# [125]	valid_0's multi_logloss: 1.15355
# [126]	valid_0's multi_logloss: 1.15176
# [127]	valid_0's multi_logloss: 1.14961
# [128]	valid_0's multi_logloss: 1.14792
# [129]	valid_0's multi_logloss: 1.14607
# [130]	valid_0's multi_logloss: 1.14446
# [131]	valid_0's multi_logloss: 1.14281
# [132]	valid_0's multi_logloss: 1.14151
# [133]	valid_0's multi_logloss: 1.13996
# [134]	valid_0's multi_logloss: 1.13814
# [135]	valid_0's multi_logloss: 1.13661
# [136]	valid_0's multi_logloss: 1.13517
# [137]	valid_0's multi_logloss: 1.13362
# [138]	valid_0's multi_logloss: 1.13237
# [139]	valid_0's multi_logloss: 1.13098
# [140]	valid_0's multi_logloss: 1.12963
# [141]	valid_0's multi_logloss: 1.12795
# [142]	valid_0's multi_logloss: 1.12621
# [143]	valid_0's multi_logloss: 1.12471
# [144]	valid_0's multi_logloss: 1.12306
# [145]	valid_0's multi_logloss: 1.12198
# [146]	valid_0's multi_logloss: 1.1207
# [147]	valid_0's multi_logloss: 1.11972
# [148]	valid_0's multi_logloss: 1.11784
# [149]	valid_0's multi_logloss: 1.1163
# [150]	valid_0's multi_logloss: 1.11494
# [151]	valid_0's multi_logloss: 1.11372
# [152]	valid_0's multi_logloss: 1.11222
# [153]	valid_0's multi_logloss: 1.11109
# [154]	valid_0's multi_logloss: 1.10968
# [155]	valid_0's multi_logloss: 1.10828
# [156]	valid_0's multi_logloss: 1.10745
# [157]	valid_0's multi_logloss: 1.10623
# [158]	valid_0's multi_logloss: 1.10483
# [159]	valid_0's multi_logloss: 1.10363
# [160]	valid_0's multi_logloss: 1.10223
# [161]	valid_0's multi_logloss: 1.10139
# [162]	valid_0's multi_logloss: 1.10021
# [163]	valid_0's multi_logloss: 1.09889
# [164]	valid_0's multi_logloss: 1.09761
# [165]	valid_0's multi_logloss: 1.09638
# [166]	valid_0's multi_logloss: 1.09518
# [167]	valid_0's multi_logloss: 1.09375
# [168]	valid_0's multi_logloss: 1.09213
# [169]	valid_0's multi_logloss: 1.09096
# [170]	valid_0's multi_logloss: 1.08986
# [171]	valid_0's multi_logloss: 1.08847
# [172]	valid_0's multi_logloss: 1.08731
# [173]	valid_0's multi_logloss: 1.08577
# [174]	valid_0's multi_logloss: 1.08474
# [175]	valid_0's multi_logloss: 1.08351
# [176]	valid_0's multi_logloss: 1.08229
# [177]	valid_0's multi_logloss: 1.08107
# [178]	valid_0's multi_logloss: 1.07998
# [179]	valid_0's multi_logloss: 1.07926
# [180]	valid_0's multi_logloss: 1.07815
# [181]	valid_0's multi_logloss: 1.07705
# [182]	valid_0's multi_logloss: 1.07595
# [183]	valid_0's multi_logloss: 1.07456
# [184]	valid_0's multi_logloss: 1.07355
# [185]	valid_0's multi_logloss: 1.07255
# [186]	valid_0's multi_logloss: 1.07154
# [187]	valid_0's multi_logloss: 1.07024
# [188]	valid_0's multi_logloss: 1.06945
# [189]	valid_0's multi_logloss: 1.06822
# [190]	valid_0's multi_logloss: 1.06676
# [191]	valid_0's multi_logloss: 1.06571
# [192]	valid_0's multi_logloss: 1.06424
# [193]	valid_0's multi_logloss: 1.06304
# [194]	valid_0's multi_logloss: 1.06154
# [195]	valid_0's multi_logloss: 1.06047
# [196]	valid_0's multi_logloss: 1.05949
# [197]	valid_0's multi_logloss: 1.05857
# [198]	valid_0's multi_logloss: 1.05747
# [199]	valid_0's multi_logloss: 1.05669
# [200]	valid_0's multi_logloss: 1.05584
# [201]	valid_0's multi_logloss: 1.05455
# [202]	valid_0's multi_logloss: 1.0532
# [203]	valid_0's multi_logloss: 1.05224
# [204]	valid_0's multi_logloss: 1.05105
# [205]	valid_0's multi_logloss: 1.0501
# [206]	valid_0's multi_logloss: 1.04908
# [207]	valid_0's multi_logloss: 1.04787
# [208]	valid_0's multi_logloss: 1.04694
# [209]	valid_0's multi_logloss: 1.046
# [210]	valid_0's multi_logloss: 1.04492
# [211]	valid_0's multi_logloss: 1.04382
# [212]	valid_0's multi_logloss: 1.0431
# [213]	valid_0's multi_logloss: 1.04204
# [214]	valid_0's multi_logloss: 1.04127
# [215]	valid_0's multi_logloss: 1.0405
# [216]	valid_0's multi_logloss: 1.03971
# [217]	valid_0's multi_logloss: 1.03877
# [218]	valid_0's multi_logloss: 1.03775
# [219]	valid_0's multi_logloss: 1.03666
# [220]	valid_0's multi_logloss: 1.03589
# [221]	valid_0's multi_logloss: 1.03512
# [222]	valid_0's multi_logloss: 1.03432
# [223]	valid_0's multi_logloss: 1.03361
# [224]	valid_0's multi_logloss: 1.03301
# [225]	valid_0's multi_logloss: 1.03229
# [226]	valid_0's multi_logloss: 1.03157
# [227]	valid_0's multi_logloss: 1.03087
# [228]	valid_0's multi_logloss: 1.03
# [229]	valid_0's multi_logloss: 1.02948
# [230]	valid_0's multi_logloss: 1.02841
# [231]	valid_0's multi_logloss: 1.02767
# [232]	valid_0's multi_logloss: 1.02703
# [233]	valid_0's multi_logloss: 1.02652
# [234]	valid_0's multi_logloss: 1.02555
# [235]	valid_0's multi_logloss: 1.02475
# [236]	valid_0's multi_logloss: 1.02402
# [237]	valid_0's multi_logloss: 1.02322
# [238]	valid_0's multi_logloss: 1.02245
# [239]	valid_0's multi_logloss: 1.02182
# [240]	valid_0's multi_logloss: 1.02113
# [241]	valid_0's multi_logloss: 1.0203
# [242]	valid_0's multi_logloss: 1.01959
# [243]	valid_0's multi_logloss: 1.01907
# [244]	valid_0's multi_logloss: 1.01824
# [245]	valid_0's multi_logloss: 1.01753
# [246]	valid_0's multi_logloss: 1.01684
# [247]	valid_0's multi_logloss: 1.01599
# [248]	valid_0's multi_logloss: 1.01535
# [249]	valid_0's multi_logloss: 1.01459
# [250]	valid_0's multi_logloss: 1.01381
# [251]	valid_0's multi_logloss: 1.01296
# [252]	valid_0's multi_logloss: 1.01174
# [253]	valid_0's multi_logloss: 1.01132
# [254]	valid_0's multi_logloss: 1.01022
# [255]	valid_0's multi_logloss: 1.00968
# [256]	valid_0's multi_logloss: 1.00882
# [257]	valid_0's multi_logloss: 1.00817
# [258]	valid_0's multi_logloss: 1.00754
# [259]	valid_0's multi_logloss: 1.00706
# [260]	valid_0's multi_logloss: 1.00626
# [261]	valid_0's multi_logloss: 1.00568
# [262]	valid_0's multi_logloss: 1.00521
# [263]	valid_0's multi_logloss: 1.00446
# [264]	valid_0's multi_logloss: 1.00379
# [265]	valid_0's multi_logloss: 1.0032
# [266]	valid_0's multi_logloss: 1.00256
# [267]	valid_0's multi_logloss: 1.00204
# [268]	valid_0's multi_logloss: 1.00136
# [269]	valid_0's multi_logloss: 1.00042
# [270]	valid_0's multi_logloss: 0.999573
# [271]	valid_0's multi_logloss: 0.998942
# [272]	valid_0's multi_logloss: 0.998208
# [273]	valid_0's multi_logloss: 0.997536
# [274]	valid_0's multi_logloss: 0.997192
# [275]	valid_0's multi_logloss: 0.996232
# [276]	valid_0's multi_logloss: 0.996081
# [277]	valid_0's multi_logloss: 0.995452
# [278]	valid_0's multi_logloss: 0.994719
# [279]	valid_0's multi_logloss: 0.994107
# [280]	valid_0's multi_logloss: 0.993375
# [281]	valid_0's multi_logloss: 0.992916
# [282]	valid_0's multi_logloss: 0.992625
# [283]	valid_0's multi_logloss: 0.992083
# [284]	valid_0's multi_logloss: 0.991658
# [285]	valid_0's multi_logloss: 0.991116
# [286]	valid_0's multi_logloss: 0.990371
# [287]	valid_0's multi_logloss: 0.989903
# [288]	valid_0's multi_logloss: 0.989383
# [289]	valid_0's multi_logloss: 0.988785
# [290]	valid_0's multi_logloss: 0.988254
# [291]	valid_0's multi_logloss: 0.987582
# [292]	valid_0's multi_logloss: 0.986971
# [293]	valid_0's multi_logloss: 0.986584
# [294]	valid_0's multi_logloss: 0.985998
# [295]	valid_0's multi_logloss: 0.985508
# [296]	valid_0's multi_logloss: 0.984882
# [297]	valid_0's multi_logloss: 0.984244
# [298]	valid_0's multi_logloss: 0.983718
# [299]	valid_0's multi_logloss: 0.983302
# [300]	valid_0's multi_logloss: 0.98287
# [301]	valid_0's multi_logloss: 0.982727
# [302]	valid_0's multi_logloss: 0.98246
# [303]	valid_0's multi_logloss: 0.981765
# [304]	valid_0's multi_logloss: 0.980928
# [305]	valid_0's multi_logloss: 0.980193
# [306]	valid_0's multi_logloss: 0.979549
# [307]	valid_0's multi_logloss: 0.978946
# [308]	valid_0's multi_logloss: 0.978215
# [309]	valid_0's multi_logloss: 0.977757
# [310]	valid_0's multi_logloss: 0.977417
# [311]	valid_0's multi_logloss: 0.976815
# [312]	valid_0's multi_logloss: 0.976331
# [313]	valid_0's multi_logloss: 0.975796
# [314]	valid_0's multi_logloss: 0.975224
# [315]	valid_0's multi_logloss: 0.974833
# [316]	valid_0's multi_logloss: 0.974243
# [317]	valid_0's multi_logloss: 0.973473
# [318]	valid_0's multi_logloss: 0.973004
# [319]	valid_0's multi_logloss: 0.972555
# [320]	valid_0's multi_logloss: 0.971825
# [321]	valid_0's multi_logloss: 0.971364
# [322]	valid_0's multi_logloss: 0.970601
# [323]	valid_0's multi_logloss: 0.970042
# [324]	valid_0's multi_logloss: 0.969799
# [325]	valid_0's multi_logloss: 0.969225
# [326]	valid_0's multi_logloss: 0.968571
# [327]	valid_0's multi_logloss: 0.968152
# [328]	valid_0's multi_logloss: 0.967835
# [329]	valid_0's multi_logloss: 0.967635
# [330]	valid_0's multi_logloss: 0.967149
# [331]	valid_0's multi_logloss: 0.966686
# [332]	valid_0's multi_logloss: 0.965979
# [333]	valid_0's multi_logloss: 0.965595
# [334]	valid_0's multi_logloss: 0.965147
# [335]	valid_0's multi_logloss: 0.964934
# [336]	valid_0's multi_logloss: 0.964414
# [337]	valid_0's multi_logloss: 0.964059
# [338]	valid_0's multi_logloss: 0.963505
# [339]	valid_0's multi_logloss: 0.963069
# [340]	valid_0's multi_logloss: 0.962467
# [341]	valid_0's multi_logloss: 0.961779
# [342]	valid_0's multi_logloss: 0.961235
# [343]	valid_0's multi_logloss: 0.960795
# [344]	valid_0's multi_logloss: 0.960376
# [345]	valid_0's multi_logloss: 0.959939
# [346]	valid_0's multi_logloss: 0.959446
# [347]	valid_0's multi_logloss: 0.959212
# [348]	valid_0's multi_logloss: 0.95866
# [349]	valid_0's multi_logloss: 0.958314
# [350]	valid_0's multi_logloss: 0.95779
# [351]	valid_0's multi_logloss: 0.957379
# [352]	valid_0's multi_logloss: 0.957144
# [353]	valid_0's multi_logloss: 0.956884
# [354]	valid_0's multi_logloss: 0.956598
# [355]	valid_0's multi_logloss: 0.956182
# [356]	valid_0's multi_logloss: 0.955897
# [357]	valid_0's multi_logloss: 0.955463
# [358]	valid_0's multi_logloss: 0.954889
# [359]	valid_0's multi_logloss: 0.954685
# [360]	valid_0's multi_logloss: 0.954375
# [361]	valid_0's multi_logloss: 0.954202
# [362]	valid_0's multi_logloss: 0.953916
# [363]	valid_0's multi_logloss: 0.953453
# [364]	valid_0's multi_logloss: 0.95309
# [365]	valid_0's multi_logloss: 0.952664
# [366]	valid_0's multi_logloss: 0.952289
# [367]	valid_0's multi_logloss: 0.951784
# [368]	valid_0's multi_logloss: 0.951308
# [369]	valid_0's multi_logloss: 0.951243
# [370]	valid_0's multi_logloss: 0.95095
# [371]	valid_0's multi_logloss: 0.950597
# [372]	valid_0's multi_logloss: 0.950226
# [373]	valid_0's multi_logloss: 0.949982
# [374]	valid_0's multi_logloss: 0.949702
# [375]	valid_0's multi_logloss: 0.948992
# [376]	valid_0's multi_logloss: 0.948638
# [377]	valid_0's multi_logloss: 0.948391
# [378]	valid_0's multi_logloss: 0.948283
# [379]	valid_0's multi_logloss: 0.947837
# [380]	valid_0's multi_logloss: 0.947656
# [381]	valid_0's multi_logloss: 0.947355
# [382]	valid_0's multi_logloss: 0.947092
# [383]	valid_0's multi_logloss: 0.946674
# [384]	valid_0's multi_logloss: 0.946458
# [385]	valid_0's multi_logloss: 0.946114
# [386]	valid_0's multi_logloss: 0.945423
# [387]	valid_0's multi_logloss: 0.945308
# [388]	valid_0's multi_logloss: 0.944865
# [389]	valid_0's multi_logloss: 0.94475
# [390]	valid_0's multi_logloss: 0.944609
# [391]	valid_0's multi_logloss: 0.944226
# [392]	valid_0's multi_logloss: 0.943984
# [393]	valid_0's multi_logloss: 0.9437
# [394]	valid_0's multi_logloss: 0.943399
# [395]	valid_0's multi_logloss: 0.943157
# [396]	valid_0's multi_logloss: 0.942763
# [397]	valid_0's multi_logloss: 0.942562
# [398]	valid_0's multi_logloss: 0.942052
# [399]	valid_0's multi_logloss: 0.941608
# [400]	valid_0's multi_logloss: 0.941196
# [401]	valid_0's multi_logloss: 0.940885
# [402]	valid_0's multi_logloss: 0.940657
# [403]	valid_0's multi_logloss: 0.940365
# [404]	valid_0's multi_logloss: 0.940268
# [405]	valid_0's multi_logloss: 0.939923
# [406]	valid_0's multi_logloss: 0.939574
# [407]	valid_0's multi_logloss: 0.939336
# [408]	valid_0's multi_logloss: 0.939028
# [409]	valid_0's multi_logloss: 0.938767
# [410]	valid_0's multi_logloss: 0.93827
# [411]	valid_0's multi_logloss: 0.937909
# [412]	valid_0's multi_logloss: 0.937426
# [413]	valid_0's multi_logloss: 0.937015
# [414]	valid_0's multi_logloss: 0.936795
# [415]	valid_0's multi_logloss: 0.936473
# ...
# [391]	valid_0's multi_logloss: 0.951398
# [392]	valid_0's multi_logloss: 0.951173
# [393]	valid_0's multi_logloss: 0.950865
# [394]	valid_0's multi_logloss: 0.950527
# [395]	valid_0's multi_logloss: 0.950233
# [396]	valid_0's multi_logloss: 0.949993
# [397]	valid_0's multi_logloss: 0.949872
# [398]	valid_0's multi_logloss: 0.949861
# [399]	valid_0's multi_logloss: 0.949621
# [400]	valid_0's multi_logloss: 0.949262
# [401]	valid_0's multi_logloss: 0.948794
# [402]	valid_0's multi_logloss: 0.948436
# [403]	valid_0's multi_logloss: 0.948243
# [404]	valid_0's multi_logloss: 0.948083
# [405]	valid_0's multi_logloss: 0.947724
# [406]	valid_0's multi_logloss: 0.947408
# [407]	valid_0's multi_logloss: 0.947183
# [408]	valid_0's multi_logloss: 0.946884
# [409]	valid_0's multi_logloss: 0.946646
# [410]	valid_0's multi_logloss: 0.946385
# [411]	valid_0's multi_logloss: 0.946047
# [412]	valid_0's multi_logloss: 0.945795
# [413]	valid_0's multi_logloss: 0.945417
# [414]	valid_0's multi_logloss: 0.945172
# [415]	valid_0's multi_logloss: 0.944828
# [416]	valid_0's multi_logloss: 0.944391
# [417]	valid_0's multi_logloss: 0.943944
# [418]	valid_0's multi_logloss: 0.943775
# [419]	valid_0's multi_logloss: 0.943492
# [420]	valid_0's multi_logloss: 0.943255
# [421]	valid_0's multi_logloss: 0.943118
# [422]	valid_0's multi_logloss: 0.94279
# [423]	valid_0's multi_logloss: 0.942553
# [424]	valid_0's multi_logloss: 0.942242
# [425]	valid_0's multi_logloss: 0.941757
# [426]	valid_0's multi_logloss: 0.94142
# [427]	valid_0's multi_logloss: 0.941096
# [428]	valid_0's multi_logloss: 0.940809
# [429]	valid_0's multi_logloss: 0.940676
# [430]	valid_0's multi_logloss: 0.940387
# [431]	valid_0's multi_logloss: 0.940215
# [432]	valid_0's multi_logloss: 0.940046
# [433]	valid_0's multi_logloss: 0.93988
# [434]	valid_0's multi_logloss: 0.939597
# [435]	valid_0's multi_logloss: 0.93931
# [436]	valid_0's multi_logloss: 0.93913
# [437]	valid_0's multi_logloss: 0.938961
# [438]	valid_0's multi_logloss: 0.938974
# [439]	valid_0's multi_logloss: 0.938747
# [440]	valid_0's multi_logloss: 0.938842
# [441]	valid_0's multi_logloss: 0.938608
# [442]	valid_0's multi_logloss: 0.938238
# [443]	valid_0's multi_logloss: 0.93804
# [444]	valid_0's multi_logloss: 0.937721
# [445]	valid_0's multi_logloss: 0.937553
# [446]	valid_0's multi_logloss: 0.937192
# [447]	valid_0's multi_logloss: 0.936754
# [448]	valid_0's multi_logloss: 0.936441
# [449]	valid_0's multi_logloss: 0.936236
# [450]	valid_0's multi_logloss: 0.935892
# [451]	valid_0's multi_logloss: 0.935833
# [452]	valid_0's multi_logloss: 0.935707
# [453]	valid_0's multi_logloss: 0.935268
# [454]	valid_0's multi_logloss: 0.93486
# [455]	valid_0's multi_logloss: 0.934722
# [456]	valid_0's multi_logloss: 0.9344
# [457]	valid_0's multi_logloss: 0.934074
# [458]	valid_0's multi_logloss: 0.933872
# [459]	valid_0's multi_logloss: 0.93359
# [460]	valid_0's multi_logloss: 0.933373
# [461]	valid_0's multi_logloss: 0.933109
# [462]	valid_0's multi_logloss: 0.933078
# [463]	valid_0's multi_logloss: 0.932857
# [464]	valid_0's multi_logloss: 0.93264
# [465]	valid_0's multi_logloss: 0.932605
# [466]	valid_0's multi_logloss: 0.932377
# [467]	valid_0's multi_logloss: 0.932259
# [468]	valid_0's multi_logloss: 0.932264
# [469]	valid_0's multi_logloss: 0.932178
# [470]	valid_0's multi_logloss: 0.931891
# [471]	valid_0's multi_logloss: 0.931705
# [472]	valid_0's multi_logloss: 0.931352
# [473]	valid_0's multi_logloss: 0.931091
# [474]	valid_0's multi_logloss: 0.930879
# [475]	valid_0's multi_logloss: 0.930985
# [476]	valid_0's multi_logloss: 0.930602
# [477]	valid_0's multi_logloss: 0.93035
# [478]	valid_0's multi_logloss: 0.930147
# [479]	valid_0's multi_logloss: 0.930029
# [480]	valid_0's multi_logloss: 0.929565
# [481]	valid_0's multi_logloss: 0.929449
# [482]	valid_0's multi_logloss: 0.929301
# [483]	valid_0's multi_logloss: 0.929069
# [484]	valid_0's multi_logloss: 0.928735
# [485]	valid_0's multi_logloss: 0.928343
# [486]	valid_0's multi_logloss: 0.9281
# [487]	valid_0's multi_logloss: 0.927761
# [488]	valid_0's multi_logloss: 0.927404
# [489]	valid_0's multi_logloss: 0.92733
# [490]	valid_0's multi_logloss: 0.927035
# [491]	valid_0's multi_logloss: 0.926764
# [492]	valid_0's multi_logloss: 0.926363
# [493]	valid_0's multi_logloss: 0.926043
# [494]	valid_0's multi_logloss: 0.925909
# [495]	valid_0's multi_logloss: 0.925596
# [496]	valid_0's multi_logloss: 0.925331
# [497]	valid_0's multi_logloss: 0.925016
# [498]	valid_0's multi_logloss: 0.924911
# [499]	valid_0's multi_logloss: 0.924809
# [500]	valid_0's multi_logloss: 0.924604
# [501]	valid_0's multi_logloss: 0.924368
# [502]	valid_0's multi_logloss: 0.924233
# [503]	valid_0's multi_logloss: 0.923913
# [504]	valid_0's multi_logloss: 0.923771
# [505]	valid_0's multi_logloss: 0.923651
# [506]	valid_0's multi_logloss: 0.923476
# [507]	valid_0's multi_logloss: 0.923393
# [508]	valid_0's multi_logloss: 0.923211
# [509]	valid_0's multi_logloss: 0.923075
# [510]	valid_0's multi_logloss: 0.922921
# [511]	valid_0's multi_logloss: 0.922826
# [512]	valid_0's multi_logloss: 0.92265
# [513]	valid_0's multi_logloss: 0.922341
# [514]	valid_0's multi_logloss: 0.922109
# [515]	valid_0's multi_logloss: 0.921718
# [516]	valid_0's multi_logloss: 0.921757
# [517]	valid_0's multi_logloss: 0.921846
# [518]	valid_0's multi_logloss: 0.921656
# [519]	valid_0's multi_logloss: 0.921475
# [520]	valid_0's multi_logloss: 0.92113
# [521]	valid_0's multi_logloss: 0.920883
# [522]	valid_0's multi_logloss: 0.920791
# [523]	valid_0's multi_logloss: 0.920616
# [524]	valid_0's multi_logloss: 0.920251
# [525]	valid_0's multi_logloss: 0.920015
# [526]	valid_0's multi_logloss: 0.919761
# [527]	valid_0's multi_logloss: 0.91983
# [528]	valid_0's multi_logloss: 0.919722
# [529]	valid_0's multi_logloss: 0.919552
# [530]	valid_0's multi_logloss: 0.919442
# [531]	valid_0's multi_logloss: 0.919215
# [532]	valid_0's multi_logloss: 0.919192
# [533]	valid_0's multi_logloss: 0.918874
# [534]	valid_0's multi_logloss: 0.918747
# [535]	valid_0's multi_logloss: 0.918392
# [536]	valid_0's multi_logloss: 0.918139
# [537]	valid_0's multi_logloss: 0.918051
# [538]	valid_0's multi_logloss: 0.91771
# [539]	valid_0's multi_logloss: 0.917817
# [540]	valid_0's multi_logloss: 0.917748
# [541]	valid_0's multi_logloss: 0.91784
# [542]	valid_0's multi_logloss: 0.917682
# [543]	valid_0's multi_logloss: 0.917433
# [544]	valid_0's multi_logloss: 0.917202
# [545]	valid_0's multi_logloss: 0.91707
# [546]	valid_0's multi_logloss: 0.917036
# [547]	valid_0's multi_logloss: 0.91697
# [548]	valid_0's multi_logloss: 0.916986
# [549]	valid_0's multi_logloss: 0.91691
# [550]	valid_0's multi_logloss: 0.916751
# [551]	valid_0's multi_logloss: 0.916492
# [552]	valid_0's multi_logloss: 0.916045
# [553]	valid_0's multi_logloss: 0.915955
# [554]	valid_0's multi_logloss: 0.915858
# [555]	valid_0's multi_logloss: 0.915868
# [556]	valid_0's multi_logloss: 0.915704
# [557]	valid_0's multi_logloss: 0.915641
# [558]	valid_0's multi_logloss: 0.915486
# [559]	valid_0's multi_logloss: 0.915391
# [560]	valid_0's multi_logloss: 0.91525
# [561]	valid_0's multi_logloss: 0.915353
# [562]	valid_0's multi_logloss: 0.915142
# [563]	valid_0's multi_logloss: 0.915179
# [564]	valid_0's multi_logloss: 0.914853
# [565]	valid_0's multi_logloss: 0.914694
# [566]	valid_0's multi_logloss: 0.914526
# [567]	valid_0's multi_logloss: 0.914425
# [568]	valid_0's multi_logloss: 0.914435
# [569]	valid_0's multi_logloss: 0.914288
# [570]	valid_0's multi_logloss: 0.914173
# [571]	valid_0's multi_logloss: 0.914013
# [572]	valid_0's multi_logloss: 0.913847
# [573]	valid_0's multi_logloss: 0.913693
# [574]	valid_0's multi_logloss: 0.913539
# [575]	valid_0's multi_logloss: 0.913308
# [576]	valid_0's multi_logloss: 0.913331
# [577]	valid_0's multi_logloss: 0.913272
# [578]	valid_0's multi_logloss: 0.913218
# [579]	valid_0's multi_logloss: 0.913084
# [580]	valid_0's multi_logloss: 0.91304
# [581]	valid_0's multi_logloss: 0.912948
# [582]	valid_0's multi_logloss: 0.912788
# [583]	valid_0's multi_logloss: 0.912829
# [584]	valid_0's multi_logloss: 0.912624
# [585]	valid_0's multi_logloss: 0.912487
# [586]	valid_0's multi_logloss: 0.912177
# [587]	valid_0's multi_logloss: 0.91208
# [588]	valid_0's multi_logloss: 0.912067
# [589]	valid_0's multi_logloss: 0.912037
# [590]	valid_0's multi_logloss: 0.911965
# [591]	valid_0's multi_logloss: 0.91191
# [592]	valid_0's multi_logloss: 0.911752
# [593]	valid_0's multi_logloss: 0.911531
# [594]	valid_0's multi_logloss: 0.911441
# [595]	valid_0's multi_logloss: 0.911338
# [596]	valid_0's multi_logloss: 0.911095
# [597]	valid_0's multi_logloss: 0.91114
# [598]	valid_0's multi_logloss: 0.910865
# [599]	valid_0's multi_logloss: 0.910816
# [600]	valid_0's multi_logloss: 0.910683
# [601]	valid_0's multi_logloss: 0.91071
# [602]	valid_0's multi_logloss: 0.910772
# [603]	valid_0's multi_logloss: 0.910738
# [604]	valid_0's multi_logloss: 0.910744
# [605]	valid_0's multi_logloss: 0.910596
# [606]	valid_0's multi_logloss: 0.910386
# [607]	valid_0's multi_logloss: 0.910328
# [608]	valid_0's multi_logloss: 0.910366
# [609]	valid_0's multi_logloss: 0.910341
# [610]	valid_0's multi_logloss: 0.910315
# [611]	valid_0's multi_logloss: 0.910308
# [612]	valid_0's multi_logloss: 0.910202
# [613]	valid_0's multi_logloss: 0.910119
# [614]	valid_0's multi_logloss: 0.910174
# [615]	valid_0's multi_logloss: 0.910055
# [616]	valid_0's multi_logloss: 0.90998
# [617]	valid_0's multi_logloss: 0.909878
# [618]	valid_0's multi_logloss: 0.909679
# [619]	valid_0's multi_logloss: 0.909628
# [620]	valid_0's multi_logloss: 0.90952
# [621]	valid_0's multi_logloss: 0.909497
# [622]	valid_0's multi_logloss: 0.909332
# [623]	valid_0's multi_logloss: 0.909285
# [624]	valid_0's multi_logloss: 0.909165
# [625]	valid_0's multi_logloss: 0.909221
# [626]	valid_0's multi_logloss: 0.909192
# [627]	valid_0's multi_logloss: 0.909027
# [628]	valid_0's multi_logloss: 0.909
# [629]	valid_0's multi_logloss: 0.908901
# [630]	valid_0's multi_logloss: 0.908874
# [631]	valid_0's multi_logloss: 0.909062
# [632]	valid_0's multi_logloss: 0.909075
# [633]	valid_0's multi_logloss: 0.909012
# [634]	valid_0's multi_logloss: 0.908985
# [635]	valid_0's multi_logloss: 0.909008
# [636]	valid_0's multi_logloss: 0.909006
# [637]	valid_0's multi_logloss: 0.909024
# [638]	valid_0's multi_logloss: 0.908852
# [639]	valid_0's multi_logloss: 0.908651
# [640]	valid_0's multi_logloss: 0.908577
# [641]	valid_0's multi_logloss: 0.908593
# [642]	valid_0's multi_logloss: 0.90863
# [643]	valid_0's multi_logloss: 0.908531
# [644]	valid_0's multi_logloss: 0.90855
# [645]	valid_0's multi_logloss: 0.908384
# [646]	valid_0's multi_logloss: 0.908422
# [647]	valid_0's multi_logloss: 0.908302
# [648]	valid_0's multi_logloss: 0.908543
# [649]	valid_0's multi_logloss: 0.908468
# [650]	valid_0's multi_logloss: 0.908478
# [651]	valid_0's multi_logloss: 0.90864
# [652]	valid_0's multi_logloss: 0.908522
# [653]	valid_0's multi_logloss: 0.908457
# [654]	valid_0's multi_logloss: 0.908344
# [655]	valid_0's multi_logloss: 0.908248
# [656]	valid_0's multi_logloss: 0.907962
# [657]	valid_0's multi_logloss: 0.907895
# [658]	valid_0's multi_logloss: 0.907828
# [659]	valid_0's multi_logloss: 0.907829
# [660]	valid_0's multi_logloss: 0.90791
# [661]	valid_0's multi_logloss: 0.90791
# [662]	valid_0's multi_logloss: 0.907746
# [663]	valid_0's multi_logloss: 0.907689
# [664]	valid_0's multi_logloss: 0.907463
# [665]	valid_0's multi_logloss: 0.907509
# [666]	valid_0's multi_logloss: 0.907599
# [667]	valid_0's multi_logloss: 0.90758
# [668]	valid_0's multi_logloss: 0.907784
# [669]	valid_0's multi_logloss: 0.907686
# [670]	valid_0's multi_logloss: 0.907766
# [671]	valid_0's multi_logloss: 0.907772
# [672]	valid_0's multi_logloss: 0.907732
# [673]	valid_0's multi_logloss: 0.907673
# [674]	valid_0's multi_logloss: 0.907515
# [675]	valid_0's multi_logloss: 0.907529
# [676]	valid_0's multi_logloss: 0.907248
# [677]	valid_0's multi_logloss: 0.907203
# [678]	valid_0's multi_logloss: 0.907256
# [679]	valid_0's multi_logloss: 0.907451
# [680]	valid_0's multi_logloss: 0.907414
# [681]	valid_0's multi_logloss: 0.907457
# [682]	valid_0's multi_logloss: 0.907436
# [683]	valid_0's multi_logloss: 0.907156
# [684]	valid_0's multi_logloss: 0.9071
# [685]	valid_0's multi_logloss: 0.907043
# [686]	valid_0's multi_logloss: 0.906951
# [687]	valid_0's multi_logloss: 0.906908
# [688]	valid_0's multi_logloss: 0.906722
# [689]	valid_0's multi_logloss: 0.906805
# [690]	valid_0's multi_logloss: 0.906688
# [691]	valid_0's multi_logloss: 0.906622
# [692]	valid_0's multi_logloss: 0.90651
# [693]	valid_0's multi_logloss: 0.906446
# [694]	valid_0's multi_logloss: 0.906396
# [695]	valid_0's multi_logloss: 0.906416
# [696]	valid_0's multi_logloss: 0.906507
# [697]	valid_0's multi_logloss: 0.906508
# [698]	valid_0's multi_logloss: 0.906237
# [699]	valid_0's multi_logloss: 0.906248
# [700]	valid_0's multi_logloss: 0.906216
# [701]	valid_0's multi_logloss: 0.906235
# [702]	valid_0's multi_logloss: 0.906153
# [703]	valid_0's multi_logloss: 0.906169
# [704]	valid_0's multi_logloss: 0.906334
# [705]	valid_0's multi_logloss: 0.90627
# [706]	valid_0's multi_logloss: 0.90638
# [707]	valid_0's multi_logloss: 0.90631
# [708]	valid_0's multi_logloss: 0.906235
# [709]	valid_0's multi_logloss: 0.906321
# [710]	valid_0's multi_logloss: 0.906317
# [711]	valid_0's multi_logloss: 0.906432
# [712]	valid_0's multi_logloss: 0.906587
# [713]	valid_0's multi_logloss: 0.906526
# [714]	valid_0's multi_logloss: 0.906531
# [715]	valid_0's multi_logloss: 0.906438
# [716]	valid_0's multi_logloss: 0.906281
# [717]	valid_0's multi_logloss: 0.906266
# [718]	valid_0's multi_logloss: 0.90626
# [719]	valid_0's multi_logloss: 0.906263
# [720]	valid_0's multi_logloss: 0.906274
# [721]	valid_0's multi_logloss: 0.906199
# [722]	valid_0's multi_logloss: 0.906291
# Early stopping, best iteration is:
# [702]	valid_0's multi_logloss: 0.906153
# F1 Score for class 0: 0.9538461538461539
# F1 Score for class 1: 0.9147826086956522
# F1 Score for class 2: 0.7288888888888888
# F1 Score for class 3: 0.9273182957393484
# F1 Score for class 4: 0.904862579281184
# F1 Score for class 5: 0.7000000000000001
# F1 Score for class 6: 0.5910931174089069
# F1 Score for class 7: 0.8547486033519552
# F1 Score for class 8: 0.4989339019189766
# F1 Score for class 9: 0.5779467680608366
# F1 Score for class 10: 0.8520710059171598
# F1 Score for class 11: 0.7298387096774194
# F1 Score for class 12: 0.746268656716418
# F1 Score for class 13: 0.764438676184296
# F1 Score for class 14: 0.9284750337381916
# F1 Score for class 15: 0.739606126914661
# F1 Score for class 16: 0.6419098143236074
# F1 Score for class 17: 0.6888888888888889
# F1 Score for class 18: 0.6510948905109489
# F1 Score for class 19: 0.5586297760210804
# F1 Score for class 20: 0.9054545454545455
# F1 Score for class 21: 0.8449905482041588
# F1 Score for class 22: 0.5984251968503937
# F1 Score for class 23: 0.861111111111111
# F1 Score for class 24: 0.7883211678832116
# F1 Score for class 25: 0.8997867803837953
# Overall F1 Score (Macro): 0.7635281479219919
# (31899, 28122) (7975, 28122)
# Seed: 1
# [1]	valid_0's multi_logloss: 2.68765
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's multi_logloss: 2.51613
# [3]	valid_0's multi_logloss: 2.39754
# [4]	valid_0's multi_logloss: 2.2818
# [5]	valid_0's multi_logloss: 2.19344
# [6]	valid_0's multi_logloss: 2.12733
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_4792\520489532.py in <module>
#      56         }
#      57
# ---> 58         model = lgbm.train(
#      59             params,
#      60             dtrain,
#
# ~\anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     290                                     evaluation_result_list=None))
#     291
# --> 292         booster.update(fobj=fobj)
#     293
#     294         evaluation_result_list = []
#
# ~\anaconda3\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    3019             if self.__set_objective_to_none:
#    3020                 raise LightGBMError('Cannot update due to null objective function.')
# -> 3021             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    3022                 self.handle,
#    3023                 ctypes.byref(is_finished)))
#
# KeyboardInterrupt:

# %%
test_preds_1 = []
test_preds_2 = []
for i in range(len(models)):
    pred = models[i].predict(X_test)
    test_preds_1.append(pred)
    test_preds_2.append(pred)
    
sorted_probs = np.sort(test_preds_1, axis=0)
test_preds_1 = np.mean(sorted_probs[:],axis=0)

y_pred_avg = np.argmax(test_preds_1, axis=1)

original_labels = le_subclass.inverse_transform(y_pred_avg)

submisson = pd.read_csv("sample_submission.csv")
submisson["SUBCLASS"] = original_labels
submisson.to_csv('fffff.csv', encoding='UTF-8-sig', index=False)
submisson["SUBCLASS"].value_counts()
# Out:
# SUBCLASS
# COAD      488
# STES      263
# BRCA      247
# LUAD      231
# PRAD      185
# KIPAN     145
# KIRC       97
# UCEC       86
# GBMLGG     84
# THCA       82
# SARC       75
# HNSC       72
# LGG        71
# SKCM       69
# OV         62
# LIHC       43
# CESC       40
# PAAD       33
# BLCA       32
# PCPG       32
# TGCT       31
# LAML       31
# ACC        17
# THYM       13
# DLBC        9
# LUSC        8
# Name: count, dtype: int64

# %%
pd.DataFrame(test_preds_1).to_csv('LGBM_FINAL_PROBA.csv', encoding='UTF-8-sig', index=False)

# %% [markdown]
# # UNTIL HERE
